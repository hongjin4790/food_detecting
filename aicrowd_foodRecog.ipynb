# %%
# Check the label of a single image
import mmengine
from collections import OrderedDict
import numpy as np
import pandas as pd
import os
import time
import matplotlib.pylab as plt
from tqdm.notebook import tqdm
import cv2

annotation = mmengine.load('./data/train/annotations.json')

# %%
annotation.keys()
# Out:
# dict_keys(['categories', 'info', 'images', 'annotations'])

# %%
# For reading annotations file
from pycocotools.coco import COCO
import json
import mmengine
from collections import OrderedDict
import numpy as np
import pandas as pd
import os
import time
import matplotlib.pylab as plt
from tqdm.notebook import tqdm
import cv2

# Reading annotations.json
TRAIN_ANNOTATIONS_PATH = "data/train/annotations.json"
TRAIN_IMAGE_DIRECTIORY = "data/train/images/"

VAL_ANNOTATIONS_PATH = "data/val/annotations.json"
VAL_IMAGE_DIRECTIORY = "data/val/images/"

train_coco = COCO(TRAIN_ANNOTATIONS_PATH)
# Out:
# loading annotations into memory...
# Done (t=3.08s)
# creating index...
# index created!

# %%
# Reading the annotation files
with open(TRAIN_ANNOTATIONS_PATH) as f:
  train_annotations_data = json.load(f)

with open(VAL_ANNOTATIONS_PATH) as f:
  val_annotations_data = json.load(f)
  
train_annotations_data['annotations'][0]
# Out:
# {'id': 184123,
#  'image_id': 131072,
#  'category_id': 101246,
#  'segmentation': [[169.0,
#    379.5,
#    130.0,
#    374.5,
#    112.0,
#    363.5,
#    94.5,
#    340.0,
#    61.5,
#    213.0,
#    61.5,
#    188.0,
#    70.5,
#    168.0,
#    87.0,
#    152.5,
#    103.0,
#    143.5,
#    123.0,
#    139.5,
#    185.0,
#    118.5,
#    226.0,
#    90.5,
#    249.0,
#    87.5,
#    309.0,
#    88.5,
#    339.0,
#    110.5,
#    350.5,
#    125.00000000000001,
#    354.5,
#    155.0,
#    382.5,
#    231.0,
#    383.5,
#    277.0,
#    360.0,
#    303.5,
#    327.0,
#    331.5,
#    308.0,
#    343.5,
#    216.0,
#    373.5]],
#  'area': 71393.0,
#  'bbox': [61.5, 61.5, 318.0, 322.0],
#  'iscrowd': 0}

# %%
category_ids = train_coco.loadCats(train_coco.getCatIds())
category_names = [cat["name_readable"] for cat in category_ids]

print("## Categories\n-", "\n- ".join(category_names))
# Out:
# ## Categories
# - Beetroot, steamed, without addition of salt
# - bread_wholemeal
# - jam
# - water
# - bread
# - banana
# - soft_cheese
# - ham_raw
# - hard_cheese
# - cottage_cheese
# - coffee
# - fruit_mixed
# - pancake
# - tea
# - salmon_smoked
# - avocado
# - spring_onion_scallion
# - ristretto_with_caffeine
# - ham_n_s
# - egg
# - bacon
# - chips_french_fries
# - juice_apple
# - chicken
# - tomato
# - broccoli
# - shrimp_prawn
# - carrot
# - chickpeas
# - french_salad_dressing
# - pasta_hornli_ch
# - sauce_cream
# - pasta_n_s
# - tomato_sauce
# - cheese_n_s
# - pear
# - cashew_nut
# - almonds
# - lentil_n_s
# - mixed_vegetables
# - peanut_butter
# - apple
# - blueberries
# - cucumber
# - yogurt
# - butter
# - mayonnaise
# - soup
# - wine_red
# - wine_white
# - green_bean_steamed_without_addition_of_salt
# - sausage
# - pizza_margherita_baked
# - salami_ch
# - mushroom
# - tart_n_s
# - rice
# - white_coffee
# - sunflower_seeds
# - bell_pepper_red_raw
# - zucchini
# - asparagus
# - tartar_sauce
# - lye_pretzel_soft
# - cucumber_pickled_ch
# - curry_vegetarian
# - soup_of_lentils_dahl_dhal
# - salmon
# - salt_cake_ch_vegetables_filled
# - orange
# - pasta_noodles
# - cream_double_cream_heavy_cream_45
# - cake_chocolate
# - pasta_spaghetti
# - black_olives
# - parmesan
# - spaetzle
# - salad_lambs_ear
# - salad_leaf_salad_green
# - potato
# - white_cabbage
# - halloumi
# - beetroot_raw
# - bread_grain
# - applesauce
# - cheese_for_raclette_ch
# - bread_white
# - curds_natural
# - quiche
# - beef_n_s
# - taboule_prepared_with_couscous
# - aubergine_eggplant
# - mozzarella
# - pasta_penne
# - lasagne_vegetable_prepared
# - mandarine
# - kiwi
# - french_beans
# - spring_roll_fried
# - caprese_salad_tomato_mozzarella
# - leaf_spinach
# - roll_of_half_white_or_white_flour_with_large_void
# - omelette_with_flour_thick_crepe_plain
# - tuna
# - dark_chocolate
# - sauce_savoury_n_s
# - raisins_dried
# - ice_tea_on_black_tea_basis
# - kaki
# - smoothie
# - crepe_with_flour_plain
# - nuggets
# - chili_con_carne_prepared
# - veggie_burger
# - chinese_cabbage
# - hamburger
# - soup_pumpkin
# - sushi
# - chestnuts_ch
# - sauce_soya
# - balsamic_salad_dressing
# - pasta_twist
# - bolognaise_sauce
# - leek
# - fajita_bread_only
# - potato_gnocchi
# - rice_noodles_vermicelli
# - bread_whole_wheat
# - onion
# - garlic
# - hummus
# - pizza_with_vegetables_baked
# - beer
# - glucose_drink_50g
# - ratatouille
# - peanut
# - cauliflower
# - green_olives
# - bread_pita
# - pasta_wholemeal
# - sauce_pesto
# - couscous
# - sauce
# - bread_toast
# - water_with_lemon_juice
# - espresso
# - egg_scrambled
# - juice_orange
# - braided_white_loaf_ch
# - emmental_cheese_ch
# - hazelnut_chocolate_spread_nutella_ovomaltine_caotina
# - tomme_ch
# - hazelnut
# - peach
# - figs
# - mashed_potatoes_prepared_with_full_fat_milk_with_butter
# - pumpkin
# - swiss_chard
# - red_cabbage_raw
# - spinach_raw
# - chicken_curry_cream_coconut_milk_curry_spices_paste
# - crunch_muesli
# - biscuit
# - meatloaf_ch
# - fresh_cheese_n_s
# - honey
# - vegetable_mix_peas_and_carrots
# - parsley
# - brownie
# - ice_cream_n_s
# - salad_dressing
# - dried_meat_n_s
# - chicken_breast
# - mixed_salad_chopped_without_sauce
# - feta
# - praline_n_s
# - walnut
# - potato_salad
# - kolhrabi
# - alfa_sprouts
# - brussel_sprouts
# - gruyere_ch
# - bulgur
# - grapes
# - chocolate_egg_small
# - cappuccino
# - crisp_bread
# - bread_black
# - rosti_n_s
# - mango
# - muesli_dry
# - spinach
# - fish_n_s
# - risotto
# - crisps_ch
# - pork_n_s
# - pomegranate
# - sweet_corn
# - flakes
# - greek_salad
# - sesame_seeds
# - bouillon
# - baked_potato
# - fennel
# - meat_n_s
# - croutons
# - bell_pepper_red_stewed
# - nuts
# - breadcrumbs_unspiced
# - fondue
# - sauce_mushroom
# - strawberries
# - pie_plum_baked_with_cake_dough
# - potatoes_au_gratin_dauphinois_prepared
# - capers
# - bread_wholemeal_toast
# - red_radish
# - fruit_tart
# - beans_kidney
# - sauerkraut
# - mustard
# - country_fries
# - ketchup
# - pasta_linguini_parpadelle_tagliatelle
# - chicken_cut_into_stripes_only_meat
# - cookies
# - sun_dried_tomatoe
# - bread_ticino_ch
# - semi_hard_cheese
# - porridge_prepared_with_partially_skimmed_milk
# - juice
# - chocolate_milk
# - bread_fruit
# - corn
# - dates
# - pistachio
# - cream_cheese_n_s
# - bread_rye
# - witloof_chicory
# - goat_cheese_soft
# - grapefruit_pomelo
# - blue_mould_cheese
# - guacamole
# - tofu
# - cordon_bleu
# - quinoa
# - kefir_drink
# - salad_rocket
# - pizza_with_ham_with_mushrooms_baked
# - fruit_coulis
# - plums
# - pizza_with_ham_baked
# - pineapple
# - seeds_n_s
# - focaccia
# - mixed_milk_beverage
# - coleslaw_chopped_without_sauce
# - sweet_potato
# - chicken_leg
# - croissant
# - cheesecake
# - sauce_cocktail
# - croissant_with_chocolate_filling
# - pumpkin_seeds
# - artichoke
# - soft_drink_with_a_taste
# - apple_pie
# - white_bread_with_butter_eggs_and_milk
# - savoury_pastry_stick
# - tuna_in_oil_drained
# - meat_terrine_pate
# - falafel_balls
# - berries_n_s
# - latte_macchiato
# - sugar_melon_galia_honeydew_cantaloupe
# - mixed_seeds_n_s
# - oil_vinegar_salad_dressing
# - celeriac
# - chocolate_mousse
# - lemon
# - chocolate_cookies
# - birchermuesli_prepared_no_sugar_added
# - muffin
# - pine_nuts
# - french_pizza_from_alsace_baked
# - chocolate_n_s
# - grits_polenta_maize_flour
# - wine_rose
# - cola_based_drink
# - raspberries
# - roll_with_pieces_of_chocolate
# - cake_lemon
# - rice_wild
# - gluten_free_bread
# - pearl_onion
# - tzatziki
# - ham_croissant_ch
# - corn_crisps
# - lentils_green_du_puy_du_berry
# - rice_whole_grain
# - cervelat_ch
# - aperitif_with_alcohol_n_s_aperol_spritz
# - peas
# - tiramisu
# - apricots
# - lasagne_meat_prepared
# - brioche
# - vegetable_au_gratin_baked
# - basil
# - butter_spread_puree_almond
# - pie_apricot
# - rusk_wholemeal
# - pasta_in_conch_form
# - pasta_in_butterfly_form_farfalle
# - damson_plum
# - shoots_n_s
# - coconut
# - banana_cake
# - sauce_curry
# - watermelon_fresh
# - white_asparagus
# - cherries
# - nectarine

# %%
no_images_per_category = {}

for n, i in enumerate(train_coco.getCatIds()):
    imgIds = train_coco.getImgIds(catIds=i)
    label = category_names[n]
    no_images_per_category[label] = len(imgIds)

no_images_per_category = OrderedDict(sorted(no_images_per_category.items(), key=lambda x: -1*x[1])) #  오름차순에서 내림차순으로 바꾸는 데 사용

# %%
# Function for taking a annotation & directiory of images and returning new annoation json with fixed image size info
def fix_data(annotations, directiory):
  for n, i in enumerate(tqdm((annotations['images']))):
   
      img = cv2.imread(directiory+i["file_name"])
 
      if img.shape[0] != i['height']:
          annotations['images'][n]['height'] = img.shape[0]
          print(i["file_name"])
          print(annotations['images'][n], img.shape)

      if img.shape[1] != i['width']:
          annotations['images'][n]['width'] = img.shape[1]
          print(i["file_name"])
          print(annotations['images'][n], img.shape)

  return annotations

train_annotations_data = fix_data(train_annotations_data, TRAIN_IMAGE_DIRECTIORY)

with open('data/train/new_ann.json', 'w') as f:
    json.dump(train_annotations_data, f)
# Out:
#   0%|          | 0/54392 [00:00<?, ?it/s]

# %%
def fix_data_val(annotations, directiory):
  for n, i in enumerate(tqdm((annotations['images']))):
      img = cv2.imread(directiory+i["file_name"])
      if img.shape[0] != i['height']:
          print(n)
          annotations['images'][n]['height'] = img.shape[0]
          print(i["file_name"])
          print(annotations['images'][n], img.shape)

      if img.shape[1] != i['width']:
          annotations['images'][n]['width'] = img.shape[1]
          print(i["file_name"])
          print(annotations['images'][n], img.shape)

  return annotations

val_annotations_data = fix_data_val(val_annotations_data, VAL_IMAGE_DIRECTIORY)

with open('data/validation/new_ann.json', 'w') as f:
    json.dump(val_annotations_data, f)
# Out:
#   0%|          | 0/946 [00:00<?, ?it/s]

# %%
train_annotations_path = 'data/train/new_ann.json'
train_images_path = 'data/train/images'

val_annotations_path = 'data/validation/new_ann.json'
val_images_path = 'data/validation/images'

# %%
# !mim download mmdet --config htc_without_semantic_r50_fpn_1x_coco --dest ./configs
# Out:
# 'mim'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
# You can add more model configs like below.
MODELS_CONFIG = {
    'htc_without_semantic_r50_fpn_1x': {
        'config_file': 'configs/htc/htc-without-semantic_r50_fpn_1x_coco.py'
    }
}

# Pick the model you want to use
selected_model = 'htc_without_semantic_r50_fpn_1x' # chose any config you want from the MODELS_CONFIG

# Name of the config file.
config_file = MODELS_CONFIG[selected_model]['config_file']

config_fname = os.path.join('mmdetection', config_file)
assert os.path.isfile(config_fname), '`{}` not exist'.format(config_fname)
config_fname
# Out:
# 'mmdetection\\configs/htc/htc-without-semantic_r50_fpn_1x_coco.py'

# %%
annotation_path = os.path.join("data", "train/new_ann.json")
json_file = open(annotation_path)
coco = json.load(json_file)
print(coco["categories"])
classes_names = [category["name"] for category in coco["categories"]]
print(classes_names)
# Out:
# [{'id': 50, 'name': 'beetroot-steamed-without-addition-of-salt', 'name_readable': 'Beetroot, steamed, without addition of salt', 'supercategory': 'food'}, {'id': 101246, 'name': 'bread_wholemeal', 'name_readable': 'bread_wholemeal', 'supercategory': 'food'}, {'id': 100546, 'name': 'jam', 'name_readable': 'jam', 'supercategory': 'food'}, {'id': 101129, 'name': 'water', 'name_readable': 'water', 'supercategory': 'food'}, {'id': 101243, 'name': 'bread', 'name_readable': 'bread', 'supercategory': 'food'}, {'id': 100133, 'name': 'banana', 'name_readable': 'banana', 'supercategory': 'food'}, {'id': 101306, 'name': 'soft_cheese', 'name_readable': 'soft_cheese', 'supercategory': 'food'}, {'id': 101126, 'name': 'ham_raw', 'name_readable': 'ham_raw', 'supercategory': 'food'}, {'id': 101305, 'name': 'hard_cheese', 'name_readable': 'hard_cheese', 'supercategory': 'food'}, {'id': 100206, 'name': 'cottage_cheese', 'name_readable': 'cottage_cheese', 'supercategory': 'food'}, {'id': 101178, 'name': 'coffee', 'name_readable': 'coffee', 'supercategory': 'food'}, {'id': 101150, 'name': 'fruit_mixed', 'name_readable': 'fruit_mixed', 'supercategory': 'food'}, {'id': 101185, 'name': 'pancake', 'name_readable': 'pancake', 'supercategory': 'food'}, {'id': 101166, 'name': 'tea', 'name_readable': 'tea', 'supercategory': 'food'}, {'id': 100966, 'name': 'salmon_smoked', 'name_readable': 'salmon_smoked', 'supercategory': 'food'}, {'id': 100078, 'name': 'avocado', 'name_readable': 'avocado', 'supercategory': 'food'}, {'id': 100107, 'name': 'spring_onion_scallion', 'name_readable': 'spring_onion_scallion', 'supercategory': 'food'}, {'id': 101181, 'name': 'ristretto_with_caffeine', 'name_readable': 'ristretto_with_caffeine', 'supercategory': 'food'}, {'id': 101335, 'name': 'ham_n_s', 'name_readable': 'ham_n_s', 'supercategory': 'food'}, {'id': 100523, 'name': 'egg', 'name_readable': 'egg', 'supercategory': 'food'}, {'id': 101291, 'name': 'bacon', 'name_readable': 'bacon', 'supercategory': 'food'}, {'id': 100063, 'name': 'chips_french_fries', 'name_readable': 'chips_french_fries', 'supercategory': 'food'}, {'id': 101219, 'name': 'juice_apple', 'name_readable': 'juice_apple', 'supercategory': 'food'}, {'id': 101308, 'name': 'chicken', 'name_readable': 'chicken', 'supercategory': 'food'}, {'id': 100089, 'name': 'tomato', 'name_readable': 'tomato', 'supercategory': 'food'}, {'id': 101183, 'name': 'broccoli', 'name_readable': 'broccoli', 'supercategory': 'food'}, {'id': 101279, 'name': 'shrimp_prawn', 'name_readable': 'shrimp_prawn', 'supercategory': 'food'}, {'id': 101188, 'name': 'carrot', 'name_readable': 'carrot', 'supercategory': 'food'}, {'id': 101311, 'name': 'chickpeas', 'name_readable': 'chickpeas', 'supercategory': 'food'}, {'id': 101214, 'name': 'french_salad_dressing', 'name_readable': 'french_salad_dressing', 'supercategory': 'food'}, {'id': 100321, 'name': 'pasta_hornli_ch', 'name_readable': 'pasta_hornli_ch', 'supercategory': 'food'}, {'id': 101275, 'name': 'sauce_cream', 'name_readable': 'sauce_cream', 'supercategory': 'food'}, {'id': 100319, 'name': 'pasta_n_s', 'name_readable': 'pasta_n_s', 'supercategory': 'food'}, {'id': 100838, 'name': 'tomato_sauce', 'name_readable': 'tomato_sauce', 'supercategory': 'food'}, {'id': 101302, 'name': 'cheese_n_s', 'name_readable': 'cheese_n_s', 'supercategory': 'food'}, {'id': 101347, 'name': 'pear', 'name_readable': 'pear', 'supercategory': 'food'}, {'id': 100184, 'name': 'cashew_nut', 'name_readable': 'cashew_nut', 'supercategory': 'food'}, {'id': 100182, 'name': 'almonds', 'name_readable': 'almonds', 'supercategory': 'food'}, {'id': 101282, 'name': 'lentil_n_s', 'name_readable': 'lentil_n_s', 'supercategory': 'food'}, {'id': 101144, 'name': 'mixed_vegetables', 'name_readable': 'mixed_vegetables', 'supercategory': 'food'}, {'id': 100175, 'name': 'peanut_butter', 'name_readable': 'peanut_butter', 'supercategory': 'food'}, {'id': 100130, 'name': 'apple', 'name_readable': 'apple', 'supercategory': 'food'}, {'id' ...
# ['beetroot-steamed-without-addition-of-salt', 'bread_wholemeal', 'jam', 'water', 'bread', 'banana', 'soft_cheese', 'ham_raw', 'hard_cheese', 'cottage_cheese', 'coffee', 'fruit_mixed', 'pancake', 'tea', 'salmon_smoked', 'avocado', 'spring_onion_scallion', 'ristretto_with_caffeine', 'ham_n_s', 'egg', 'bacon', 'chips_french_fries', 'juice_apple', 'chicken', 'tomato', 'broccoli', 'shrimp_prawn', 'carrot', 'chickpeas', 'french_salad_dressing', 'pasta_hornli_ch', 'sauce_cream', 'pasta_n_s', 'tomato_sauce', 'cheese_n_s', 'pear', 'cashew_nut', 'almonds', 'lentil_n_s', 'mixed_vegetables', 'peanut_butter', 'apple', 'blueberries', 'cucumber', 'yogurt', 'butter', 'mayonnaise', 'soup', 'wine_red', 'wine_white', 'green_bean_steamed_without_addition_of_salt', 'sausage', 'pizza_margherita_baked', 'salami_ch', 'mushroom', 'tart_n_s', 'rice', 'white_coffee', 'sunflower_seeds', 'bell_pepper_red_raw', 'zucchini', 'asparagus', 'tartar_sauce', 'lye_pretzel_soft', 'cucumber_pickled_ch', 'curry_vegetarian', 'soup_of_lentils_dahl_dhal', 'salmon', 'salt_cake_ch_vegetables_filled', 'orange', 'pasta_noodles', 'cream_double_cream_heavy_cream_45', 'cake_chocolate', 'pasta_spaghetti', 'black_olives', 'parmesan', 'spaetzle', 'salad_lambs_ear', 'salad_leaf_salad_green', 'potato', 'white_cabbage', 'halloumi', 'beetroot_raw', 'bread_grain', 'applesauce', 'cheese_for_raclette_ch', 'bread_white', 'curds_natural', 'quiche', 'beef_n_s', 'taboule_prepared_with_couscous', 'aubergine_eggplant', 'mozzarella', 'pasta_penne', 'lasagne_vegetable_prepared', 'mandarine', 'kiwi', 'french_beans', 'spring_roll_fried', 'caprese_salad_tomato_mozzarella', 'leaf_spinach', 'roll_of_half_white_or_white_flour_with_large_void', 'omelette_with_flour_thick_crepe_plain', 'tuna', 'dark_chocolate', 'sauce_savoury_n_s', 'raisins_dried', 'ice_tea_on_black_tea_basis', 'kaki', 'smoothie', 'crepe_with_flour_plain', 'nuggets', 'chili_con_carne_prepared', 'veggie_burger', 'chinese_cabbage', 'hamburger', 'soup_pumpkin', 'sushi', 'chestnuts_ch', 'sauce_soya', 'balsamic_salad_dressing', 'pasta_twist', 'bolognaise_sauce', 'leek', 'fajita_bread_only', 'potato_gnocchi', 'rice_noodles_vermicelli', 'bread_whole_wheat', 'onion', 'garlic', 'hummus', 'pizza_with_vegetables_baked', 'beer', 'glucose_drink_50g', 'ratatouille', 'peanut', 'cauliflower', 'green_olives', 'bread_pita', 'pasta_wholemeal', 'sauce_pesto', 'couscous', 'sauce', 'bread_toast', 'water_with_lemon_juice', 'espresso', 'egg_scrambled', 'juice_orange', 'braided_white_loaf_ch', 'emmental_cheese_ch', 'hazelnut_chocolate_spread_nutella_ovomaltine_caotina', 'tomme_ch', 'hazelnut', 'peach', 'figs', 'mashed_potatoes_prepared_with_full_fat_milk_with_butter', 'pumpkin', 'swiss_chard', 'red_cabbage_raw', 'spinach_raw', 'chicken_curry_cream_coconut_milk_curry_spices_paste', 'crunch_muesli', 'biscuit', 'meatloaf_ch', 'fresh_cheese_n_s', 'honey', 'vegetable_mix_peas_and_carrots', 'parsley', 'brownie', 'ice_cream_n_s', 'salad_dressing', 'dried_meat_n_s', 'chicken_breast', 'mixed_salad_chopped_without_sauce', 'feta', 'praline_n_s', 'walnut', 'potato_salad', 'kolhrabi', 'alfa_sprouts', 'brussel_sprouts', 'gruyere_ch', 'bulgur', 'grapes', 'chocolate_egg_small', 'cappuccino', 'crisp_bread', 'bread_black', 'rosti_n_s', 'mango', 'muesli_dry', 'spinach', 'fish_n_s', 'risotto', 'crisps_ch', 'pork_n_s', 'pomegranate', 'sweet_corn', 'flakes', 'greek_salad', 'sesame_seeds', 'bouillon', 'baked_potato', 'fennel', 'meat_n_s', 'croutons', 'bell_pepper_red_stewed', 'nuts', 'breadcrumbs_unspiced', 'fondue', 'sauce_mushroom', 'strawberries', 'pie_plum_baked_with_cake_dough', 'potatoes_au_gratin_dauphinois_prepared', 'capers', 'bread_wholemeal_toast', 'red_radish', 'fruit_tart', 'beans_kidney', 'sauerkraut', 'mustard', 'country_fries', 'ketchup', 'pasta_linguini_parpadelle_tagliatelle', 'chicken_cut_into_stripes_only_meat', 'cookies', 'sun_dried_tomatoe', 'bread_ticino_ch', 'semi_hard_cheese', 'porridge_prepared_with_partially_skimmed_milk', 'juice', 'chocolate_milk', 'bread ...

# %%
## configs 파일에서 num_classes 323 으로 변경
import re
fname = config_fname
with open(fname) as f:
    s = f.read()

    s = re.sub('num_classes=.*?,',
               'num_classes={},'.format(len(classes_names)), s)

with open(fname, 'w') as f:
    f.write(s)

# %%
import re
fname2 = './mmdetection/configs/_base_/datasets/coco_instance.py'

with open(fname2) as f:
    s = f.read()
    s = re.sub("data_root = 'data/coco/'",
                "data_root = 'data/'", s)
    s = re.sub("annotations/instances_train2017.json",
                "train/new_ann.json", s)
    s = re.sub("annotations/instances_val2017.json",
                "val/new_ann.json", s)
    s = re.sub("annotations/instances_val2017.json",
                "val/new_ann.json", s)
    s = re.sub("train2017", "train/images", s)
    s = re.sub("val2017", "val/images", s)
    s = re.sub("workers_per_gpu=2","workers_per_gpu=2",s)
    s = re.sub("samples_per_gpu=2","samples_per_gpu=6",s) 

with open(fname2, 'w') as f:
    f.write(s)


total_epochs = 22
fname = './mmdetection/configs/_base_/schedules/schedule_1x.py'
with open(fname) as f:
    s = f.read()
    s = re.sub('max_epochs=\d+',
               'max_epochs={}'.format(total_epochs), s)
    s = re.sub("lr=0.02","lr=0.0025",s)  #need to change lr to 0.0025 since we are working with only 1 gpu
with open(fname, 'w') as f:
    f.write(s)

# %%
# %%writefile ./mmdetection/mmdet/datasets/coco.py

import contextlib
import io
import itertools
import logging
import os.path as osp
import tempfile
import warnings
from collections import OrderedDict

import mmcv
import numpy as np
from mmcv.utils import print_log
from terminaltables import AsciiTable

from mmdet.core import eval_recalls
from .api_wrappers import COCO, COCOeval
from .builder import DATASETS
from .custom import CustomDataset


@DATASETS.register_module()
class CocoDataset(CustomDataset):
    CLASSES = ('beetroot-steamed-without-addition-of-salt', 
    'bread_wholemeal', 'jam', 'water', 'bread', 'banana', 'soft_cheese', 'ham_raw', 'hard_cheese', 
    'cottage_cheese', 'coffee', 'fruit_mixed', 'pancake', 'tea', 'salmon_smoked', 'avocado', 'spring_onion_scallion',
     'ristretto_with_caffeine', 'ham_n_s', 'egg', 'bacon', 'chips_french_fries', 'juice_apple', 'chicken', 'tomato', 
     'broccoli', 'shrimp_prawn', 'carrot', 'chickpeas', 'french_salad_dressing', 'pasta_hornli_ch', 'sauce_cream', 'pasta_n_s', 
     'tomato_sauce', 'cheese_n_s', 'pear', 'cashew_nut', 'almonds', 'lentil_n_s', 'mixed_vegetables', 'peanut_butter', 'apple', 
     'blueberries', 'cucumber', 'yogurt', 'butter', 'mayonnaise', 'soup', 'wine_red', 'wine_white', 'green_bean_steamed_without_addition_of_salt', 
     'sausage', 'pizza_margherita_baked', 'salami_ch', 'mushroom', 'tart_n_s', 'rice', 'white_coffee', 'sunflower_seeds', 'bell_pepper_red_raw', 
     'zucchini', 'asparagus', 'tartar_sauce', 'lye_pretzel_soft', 'cucumber_pickled_ch', 'curry_vegetarian', 'soup_of_lentils_dahl_dhal', 'salmon', 
     'salt_cake_ch_vegetables_filled', 'orange', 'pasta_noodles', 'cream_double_cream_heavy_cream_45', 'cake_chocolate', 'pasta_spaghetti', 
     'black_olives', 'parmesan', 'spaetzle', 'salad_lambs_ear', 'salad_leaf_salad_green', 'potato', 'white_cabbage', 'halloumi', 'beetroot_raw', 
     'bread_grain', 'applesauce', 'cheese_for_raclette_ch', 'bread_white', 'curds_natural', 'quiche', 'beef_n_s', 'taboule_prepared_with_couscous',
      'aubergine_eggplant', 'mozzarella', 'pasta_penne', 'lasagne_vegetable_prepared', 'mandarine', 'kiwi', 'french_beans', 'spring_roll_fried', 
      'caprese_salad_tomato_mozzarella', 'leaf_spinach', 'roll_of_half_white_or_white_flour_with_large_void', 'omelette_with_flour_thick_crepe_plain', 'tuna', 'dark_chocolate', 'sauce_savoury_n_s', 'raisins_dried', 'ice_tea_on_black_tea_basis', 'kaki', 'smoothie', 'crepe_with_flour_plain', 'nuggets', 'chili_con_carne_prepared', 'veggie_burger', 'chinese_cabbage', 'hamburger', 'soup_pumpkin', 'sushi', 'chestnuts_ch', 'sauce_soya', 'balsamic_salad_dressing', 'pasta_twist', 'bolognaise_sauce', 'leek', 'fajita_bread_only', 'potato_gnocchi', 'rice_noodles_vermicelli', 'bread_whole_wheat', 'onion', 'garlic', 'hummus', 'pizza_with_vegetables_baked', 'beer', 'glucose_drink_50g', 'ratatouille', 'peanut', 'cauliflower', 'green_olives', 'bread_pita', 'pasta_wholemeal', 'sauce_pesto', 'couscous', 'sauce', 'bread_toast', 'water_with_lemon_juice', 'espresso', 'egg_scrambled', 'juice_orange', 'braided_white_loaf_ch', 'emmental_cheese_ch', 'hazelnut_chocolate_spread_nutella_ovomaltine_caotina', 'tomme_ch', 'hazelnut', 'peach', 'figs', 'mashed_potatoes_prepared_with_full_fat_milk_with_butter', 'pumpkin', 'swiss_chard', 'red_cabbage_raw', 'spinach_raw', 'chicken_curry_cream_coconut_milk_curry_spices_paste', 'crunch_muesli', 'biscuit', 'meatloaf_ch', 'fresh_cheese_n_s', 'honey', 'vegetable_mix_peas_and_carrots', 'parsley', 'brownie', 'ice_cream_n_s', 'salad_dressing', 'dried_meat_n_s', 'chicken_breast', 'mixed_salad_chopped_without_sauce', 'feta', 'praline_n_s', 'walnut', 'potato_salad', 'kolhrabi', 'alfa_sprouts', 'brussel_sprouts', 'gruyere_ch', 'bulgur', 'grapes', 'chocolate_egg_small', 'cappuccino', 'crisp_bread', 'bread_black', 'rosti_n_s', 'mango', 'muesli_dry', 'spinach', 'fish_n_s', 'risotto', 'crisps_ch', 'pork_n_s', 'pomegranate', 'sweet_corn', 'flakes', 'greek_salad', 'sesame_seeds', 'bouillon', 'baked_potato', 'fennel', 'meat_n_s', 'croutons', 'bell_pepper_red_stewed', 'nuts', 'breadcrumbs_unspiced', 'fondue', 'sauce_mushroom', 'strawberries', 'pie_plum_baked_with_cake_dough', 'potatoes_au_gratin_dauphinois_prepared', 'capers', 'bread_wholemeal_toast', 'red_radish', 'fruit_tart', 'beans_kidney', 'sauerkraut', 'mustard', 'country_fries', 'ketchup', 'pasta_linguini_parpadelle_tagliatelle', 'chicken_cut_into_stripes_only_meat', 'cookies', 'sun_dried_tomatoe', 'bread_ticino_ch', 'semi_hard_cheese', 'porridge_prepared_with_partially_skimmed_milk', 'juice', 'chocolate_milk', 'bread_fruit', 'corn', 'dates', 'pistachio', 'cream_cheese_n_s', 'bread_rye', 'witloof_chicory', 'goat_cheese_soft', 'grapefruit_pomelo', 'blue_mould_cheese', 'guacamole', 'tofu', 'cordon_bleu', 'quinoa', 'kefir_drink', 'salad_rocket', 'pizza_with_ham_with_mushrooms_baked', 'fruit_coulis', 'plums', 'pizza_with_ham_baked', 'pineapple', 'seeds_n_s', 'focaccia', 'mixed_milk_beverage', 'coleslaw_chopped_without_sauce', 'sweet_potato', 'chicken_leg', 'croissant', 'cheesecake', 'sauce_cocktail', 'croissant_with_chocolate_filling', 'pumpkin_seeds', 'artichoke', 'soft_drink_with_a_taste', 'apple_pie', 'white_bread_with_butter_eggs_and_milk', 'savoury_pastry_stick', 'tuna_in_oil_drained', 'meat_terrine_pate', 'falafel_balls', 'berries_n_s', 'latte_macchiato', 'sugar_melon_galia_honeydew_cantaloupe', 'mixed_seeds_n_s', 'oil_vinegar_salad_dressing', 'celeriac', 'chocolate_mousse', 'lemon', 'chocolate_cookies', 'birchermuesli_prepared_no_sugar_added', 'muffin', 'pine_nuts', 'french_pizza_from_alsace_baked', 'chocolate_n_s', 'grits_polenta_maize_flour', 'wine_rose', 'cola_based_drink', 'raspberries', 'roll_with_pieces_of_chocolate', 'cake_lemon', 'rice_wild', 'gluten_free_bread', 'pearl_onion', 'tzatziki', 'ham_croissant_ch', 'corn_crisps', 'lentils_green_du_puy_du_berry', 'rice_whole_grain', 'cervelat_ch', 'aperitif_with_alcohol_n_s_aperol_spritz', 'peas', 'tiramisu', 'apricots', 'lasagne_meat_prepared', 'brioche', 'vegetable_au_gratin_baked', 'basil', 'butter_spread_puree_almond', 'pie_apricot', 'rusk_wholemeal', 'pasta_in_conch_form', 'pasta_in_butterfly_form_farfalle', 
    'damson_plum', 'shoots_n_s', 'coconut', 'banana_cake', 'sauce_curry', 'watermelon_fresh', 'white_asparagus', 'cherries', 'nectarine')

    def load_annotations(self, ann_file):
        """Load annotation from COCO style annotation file.

        Args:
            ann_file (str): Path of annotation file.

        Returns:
            list[dict]: Annotation info from COCO api.
        """

        self.coco = COCO(ann_file)
        # The order of returned `cat_ids` will not
        # change with the order of the CLASSES
        self.cat_ids = self.coco.getCatIds()

        self.cat2label = {cat_id: i for i, cat_id in enumerate(self.cat_ids)}
        self.img_ids = self.coco.getImgIds()
        data_infos = []
        total_ann_ids = []
        for i in self.img_ids:
            info = self.coco.load_imgs([i])[0]
            info['filename'] = info['file_name']
            data_infos.append(info)
            ann_ids = self.coco.get_ann_ids(img_ids=[i])
            total_ann_ids.extend(ann_ids)
        assert len(set(total_ann_ids)) == len(
            total_ann_ids), f"Annotation ids in '{ann_file}' are not unique!"
        return data_infos

    def get_ann_info(self, idx):
        """Get COCO annotation by index.

        Args:
            idx (int): Index of data.

        Returns:
            dict: Annotation info of specified index.
        """

        img_id = self.data_infos[idx]['id']
        ann_ids = self.coco.get_ann_ids(img_ids=[img_id])
        ann_info = self.coco.load_anns(ann_ids)
        return self._parse_ann_info(self.data_infos[idx], ann_info)

    def getCatIds(self, idx):
        """Get COCO category ids by index.

        Args:
            idx (int): Index of data.

        Returns:
            list[int]: All categories in the image of specified index.
        """

        img_id = self.data_infos[idx]['id']
        ann_ids = self.coco.get_ann_ids(img_ids=[img_id])
        ann_info = self.coco.load_anns(ann_ids)
        return [ann['category_id'] for ann in ann_info]

    def _filter_imgs(self, min_size=32):
        """Filter images too small or without ground truths."""
        valid_inds = []
        # obtain images that contain annotation
        ids_with_ann = set(_['image_id'] for _ in self.coco.anns.values())
        # obtain images that contain annotations of the required categories
        ids_in_cat = set()
        for i, class_id in enumerate(self.cat_ids):
            ids_in_cat |= set(self.coco.cat_img_map[class_id])
        # merge the image id sets of the two conditions and use the merged set
        # to filter out images if self.filter_empty_gt=True
        ids_in_cat &= ids_with_ann

        valid_img_ids = []
        for i, img_info in enumerate(self.data_infos):
            img_id = self.img_ids[i]
            if self.filter_empty_gt and img_id not in ids_in_cat:
                continue
            if min(img_info['width'], img_info['height']) >= min_size:
                valid_inds.append(i)
                valid_img_ids.append(img_id)
        self.img_ids = valid_img_ids
        return valid_inds

    def _parse_ann_info(self, img_info, ann_info):
        """Parse bbox and mask annotation.

        Args:
            ann_info (list[dict]): Annotation info of an image.
            with_mask (bool): Whether to parse mask annotations.

        Returns:
            dict: A dict containing the following keys: bboxes, bboxes_ignore,\
                labels, masks, seg_map. "masks" are raw annotations and not \
                decoded into binary masks.
        """
        gt_bboxes = []
        gt_labels = []
        gt_bboxes_ignore = []
        gt_masks_ann = []
        for i, ann in enumerate(ann_info):
            if ann.get('ignore', False):
                continue
            x1, y1, w, h = ann['bbox']
            inter_w = max(0, min(x1 + w, img_info['width']) - max(x1, 0))
            inter_h = max(0, min(y1 + h, img_info['height']) - max(y1, 0))
            if inter_w * inter_h == 0:
                continue
            if ann['area'] <= 0 or w < 1 or h < 1:
                continue
            if ann['category_id'] not in self.cat_ids:
                continue
            bbox = [x1, y1, x1 + w, y1 + h]
            if ann.get('iscrowd', False):
                gt_bboxes_ignore.append(bbox)
            else:
                gt_bboxes.append(bbox)
                gt_labels.append(self.cat2label[ann['category_id']])
                gt_masks_ann.append(ann.get('segmentation', None))

        if gt_bboxes:
            gt_bboxes = np.array(gt_bboxes, dtype=np.float32)
            gt_labels = np.array(gt_labels, dtype=np.int64)
        else:
            gt_bboxes = np.zeros((0, 4), dtype=np.float32)
            gt_labels = np.array([], dtype=np.int64)

        if gt_bboxes_ignore:
            gt_bboxes_ignore = np.array(gt_bboxes_ignore, dtype=np.float32)
        else:
            gt_bboxes_ignore = np.zeros((0, 4), dtype=np.float32)

        seg_map = img_info['filename'].replace('jpg', 'png')

        ann = dict(
            bboxes=gt_bboxes,
            labels=gt_labels,
            bboxes_ignore=gt_bboxes_ignore,
            masks=gt_masks_ann,
            seg_map=seg_map)

        return ann

    def xyxy2xywh(self, bbox):
        """Convert ``xyxy`` style bounding boxes to ``xywh`` style for COCO
        evaluation.

        Args:
            bbox (numpy.ndarray): The bounding boxes, shape (4, ), in
                ``xyxy`` order.

        Returns:
            list[float]: The converted bounding boxes, in ``xywh`` order.
        """

        _bbox = bbox.tolist()
        return [
            _bbox[0],
            _bbox[1],
            _bbox[2] - _bbox[0],
            _bbox[3] - _bbox[1],
        ]

    def _proposal2json(self, results):
        """Convert proposal results to COCO json style."""
        json_results = []
        for idx in range(len(self)):
            img_id = self.img_ids[idx]
            bboxes = results[idx]
            for i in range(bboxes.shape[0]):
                data = dict()
                data['image_id'] = img_id
                data['bbox'] = self.xyxy2xywh(bboxes[i])
                data['score'] = float(bboxes[i][4])
                data['category_id'] = 1
                json_results.append(data)
        return json_results

    def _det2json(self, results):
        """Convert detection results to COCO json style."""
        json_results = []
        for idx in range(len(self)):
            img_id = self.img_ids[idx]
            result = results[idx]
            for label in range(len(result)):
                bboxes = result[label]
                for i in range(bboxes.shape[0]):
                    data = dict()
                    data['image_id'] = img_id
                    data['bbox'] = self.xyxy2xywh(bboxes[i])
                    data['score'] = float(bboxes[i][4])
                    data['category_id'] = self.cat_ids[label]
                    json_results.append(data)
        return json_results

    def _segm2json(self, results):
        """Convert instance segmentation results to COCO json style."""
        bbox_json_results = []
        segm_json_results = []
        for idx in range(len(self)):
            img_id = self.img_ids[idx]
            det, seg = results[idx]
            for label in range(len(det)):
                # bbox results
                bboxes = det[label]
                for i in range(bboxes.shape[0]):
                    data = dict()
                    data['image_id'] = img_id
                    data['bbox'] = self.xyxy2xywh(bboxes[i])
                    data['score'] = float(bboxes[i][4])
                    data['category_id'] = self.cat_ids[label]
                    bbox_json_results.append(data)

                # segm results
                # some detectors use different scores for bbox and mask
                if isinstance(seg, tuple):
                    segms = seg[0][label]
                    mask_score = seg[1][label]
                else:
                    segms = seg[label]
                    mask_score = [bbox[4] for bbox in bboxes]
                for i in range(bboxes.shape[0]):
                    data = dict()
                    data['image_id'] = img_id
                    data['bbox'] = self.xyxy2xywh(bboxes[i])
                    data['score'] = float(mask_score[i])
                    data['category_id'] = self.cat_ids[label]
                    if isinstance(segms[i]['counts'], bytes):
                        segms[i]['counts'] = segms[i]['counts'].decode()
                    data['segmentation'] = segms[i]
                    segm_json_results.append(data)
        return bbox_json_results, segm_json_results

    def results2json(self, results, outfile_prefix):
        """Dump the detection results to a COCO style json file.

        There are 3 types of results: proposals, bbox predictions, mask
        predictions, and they have different data types. This method will
        automatically recognize the type, and dump them to json files.

        Args:
            results (list[list | tuple | ndarray]): Testing results of the
                dataset.
            outfile_prefix (str): The filename prefix of the json files. If the
                prefix is "somepath/xxx", the json files will be named
                "somepath/xxx.bbox.json", "somepath/xxx.segm.json",
                "somepath/xxx.proposal.json".

        Returns:
            dict[str: str]: Possible keys are "bbox", "segm", "proposal", and \
                values are corresponding filenames.
        """
        result_files = dict()
        if isinstance(results[0], list):
            json_results = self._det2json(results)
            result_files['bbox'] = f'{outfile_prefix}.bbox.json'
            result_files['proposal'] = f'{outfile_prefix}.bbox.json'
            mmcv.dump(json_results, result_files['bbox'])
        elif isinstance(results[0], tuple):
            json_results = self._segm2json(results)
            result_files['bbox'] = f'{outfile_prefix}.bbox.json'
            result_files['proposal'] = f'{outfile_prefix}.bbox.json'
            result_files['segm'] = f'{outfile_prefix}.segm.json'
            mmcv.dump(json_results[0], result_files['bbox'])
            mmcv.dump(json_results[1], result_files['segm'])
        elif isinstance(results[0], np.ndarray):
            json_results = self._proposal2json(results)
            result_files['proposal'] = f'{outfile_prefix}.proposal.json'
            mmcv.dump(json_results, result_files['proposal'])
        else:
            raise TypeError('invalid type of results')
        return result_files

    def fast_eval_recall(self, results, proposal_nums, iou_thrs, logger=None):
        gt_bboxes = []
        for i in range(len(self.img_ids)):
            ann_ids = self.coco.get_ann_ids(img_ids=self.img_ids[i])
            ann_info = self.coco.load_anns(ann_ids)
            if len(ann_info) == 0:
                gt_bboxes.append(np.zeros((0, 4)))
                continue
            bboxes = []
            for ann in ann_info:
                if ann.get('ignore', False) or ann['iscrowd']:
                    continue
                x1, y1, w, h = ann['bbox']
                bboxes.append([x1, y1, x1 + w, y1 + h])
            bboxes = np.array(bboxes, dtype=np.float32)
            if bboxes.shape[0] == 0:
                bboxes = np.zeros((0, 4))
            gt_bboxes.append(bboxes)

        recalls = eval_recalls(
            gt_bboxes, results, proposal_nums, iou_thrs, logger=logger)
        ar = recalls.mean(axis=1)
        return ar

    def format_results(self, results, jsonfile_prefix=None, **kwargs):
        """Format the results to json (standard format for COCO evaluation).

        Args:
            results (list[tuple | numpy.ndarray]): Testing results of the
                dataset.
            jsonfile_prefix (str | None): The prefix of json files. It includes
                the file path and the prefix of filename, e.g., "a/b/prefix".
                If not specified, a temp file will be created. Default: None.

        Returns:
            tuple: (result_files, tmp_dir), result_files is a dict containing \
                the json filepaths, tmp_dir is the temporal directory created \
                for saving json files when jsonfile_prefix is not specified.
        """
        assert isinstance(results, list), 'results must be a list'
        assert len(results) == len(self), (
            'The length of results is not equal to the dataset len: {} != {}'.
            format(len(results), len(self)))

        if jsonfile_prefix is None:
            tmp_dir = tempfile.TemporaryDirectory()
            jsonfile_prefix = osp.join(tmp_dir.name, 'results')
        else:
            tmp_dir = None
        result_files = self.results2json(results, jsonfile_prefix)
        return result_files, tmp_dir

    def evaluate(self,
                 results,
                 metric='bbox',
                 logger=None,
                 jsonfile_prefix=None,
                 classwise=False,
                 proposal_nums=(100, 300, 1000),
                 iou_thrs=None,
                 metric_items=None):
        """Evaluation in COCO protocol.

        Args:
            results (list[list | tuple]): Testing results of the dataset.
            metric (str | list[str]): Metrics to be evaluated. Options are
                'bbox', 'segm', 'proposal', 'proposal_fast'.
            logger (logging.Logger | str | None): Logger used for printing
                related information during evaluation. Default: None.
            jsonfile_prefix (str | None): The prefix of json files. It includes
                the file path and the prefix of filename, e.g., "a/b/prefix".
                If not specified, a temp file will be created. Default: None.
            classwise (bool): Whether to evaluating the AP for each class.
            proposal_nums (Sequence[int]): Proposal number used for evaluating
                recalls, such as recall@100, recall@1000.
                Default: (100, 300, 1000).
            iou_thrs (Sequence[float], optional): IoU threshold used for
                evaluating recalls/mAPs. If set to a list, the average of all
                IoUs will also be computed. If not specified, [0.50, 0.55,
                0.60, 0.65, 0.70, 0.75, 0.80, 0.85, 0.90, 0.95] will be used.
                Default: None.
            metric_items (list[str] | str, optional): Metric items that will
                be returned. If not specified, ``['AR@100', 'AR@300',
                'AR@1000', 'AR_s@1000', 'AR_m@1000', 'AR_l@1000' ]`` will be
                used when ``metric=='proposal'``, ``['mAP', 'mAP_50', 'mAP_75',
                'mAP_s', 'mAP_m', 'mAP_l']`` will be used when
                ``metric=='bbox' or metric=='segm'``.

        Returns:
            dict[str, float]: COCO style evaluation metric.
        """

        metrics = metric if isinstance(metric, list) else [metric]
        allowed_metrics = ['bbox', 'segm', 'proposal', 'proposal_fast']
        for metric in metrics:
            if metric not in allowed_metrics:
                raise KeyError(f'metric {metric} is not supported')
        if iou_thrs is None:
            iou_thrs = np.linspace(
                .5, 0.95, int(np.round((0.95 - .5) / .05)) + 1, endpoint=True)
        if metric_items is not None:
            if not isinstance(metric_items, list):
                metric_items = [metric_items]

        result_files, tmp_dir = self.format_results(results, jsonfile_prefix)

        eval_results = OrderedDict()
        cocoGt = self.coco
        for metric in metrics:
            msg = f'Evaluating {metric}...'
            if logger is None:
                msg = '\n' + msg
            print_log(msg, logger=logger)

            if metric == 'proposal_fast':
                ar = self.fast_eval_recall(
                    results, proposal_nums, iou_thrs, logger='silent')
                log_msg = []
                for i, num in enumerate(proposal_nums):
                    eval_results[f'AR@{num}'] = ar[i]
                    log_msg.append(f'\nAR@{num}\t{ar[i]:.4f}')
                log_msg = ''.join(log_msg)
                print_log(log_msg, logger=logger)
                continue

            iou_type = 'bbox' if metric == 'proposal' else metric
            if metric not in result_files:
                raise KeyError(f'{metric} is not in results')
            try:
                predictions = mmcv.load(result_files[metric])
                if iou_type == 'segm':
                    # Refer to https://github.com/cocodataset/cocoapi/blob/master/PythonAPI/pycocotools/coco.py#L331  # noqa
                    # When evaluating mask AP, if the results contain bbox,
                    # cocoapi will use the box area instead of the mask area
                    # for calculating the instance area. Though the overall AP
                    # is not affected, this leads to different
                    # small/medium/large mask AP results.
                    for x in predictions:
                        x.pop('bbox')
                    warnings.simplefilter('once')
                    warnings.warn(
                        'The key "bbox" is deleted for more accurate mask AP '
                        'of small/medium/large instances since v2.12.0. This '
                        'does not change the overall mAP calculation.',
                        UserWarning)
                cocoDt = cocoGt.loadRes(predictions)
            except IndexError:
                print_log(
                    'The testing results of the whole dataset is empty.',
                    logger=logger,
                    level=logging.ERROR)
                break

            cocoEval = COCOeval(cocoGt, cocoDt, iou_type)
            cocoEval.params.catIds = self.cat_ids
            cocoEval.params.imgIds = self.img_ids
            cocoEval.params.maxDets = list(proposal_nums)
            cocoEval.params.iouThrs = iou_thrs
            # mapping of cocoEval.stats
            coco_metric_names = {
                'mAP': 0,
                'mAP_50': 1,
                'mAP_75': 2,
                'mAP_s': 3,
                'mAP_m': 4,
                'mAP_l': 5,
                'AR@100': 6,
                'AR@300': 7,
                'AR@1000': 8,
                'AR_s@1000': 9,
                'AR_m@1000': 10,
                'AR_l@1000': 11
            }
            if metric_items is not None:
                for metric_item in metric_items:
                    if metric_item not in coco_metric_names:
                        raise KeyError(
                            f'metric item {metric_item} is not supported')

            if metric == 'proposal':
                cocoEval.params.useCats = 0
                cocoEval.evaluate()
                cocoEval.accumulate()

                # Save coco summarize print information to logger
                redirect_string = io.StringIO()
                with contextlib.redirect_stdout(redirect_string):
                    cocoEval.summarize()
                print_log('\n' + redirect_string.getvalue(), logger=logger)

                if metric_items is None:
                    metric_items = [
                        'AR@100', 'AR@300', 'AR@1000', 'AR_s@1000',
                        'AR_m@1000', 'AR_l@1000'
                    ]

                for item in metric_items:
                    val = float(
                        f'{cocoEval.stats[coco_metric_names[item]]:.3f}')
                    eval_results[item] = val
            else:
                cocoEval.evaluate()
                cocoEval.accumulate()

                # Save coco summarize print information to logger
                redirect_string = io.StringIO()
                with contextlib.redirect_stdout(redirect_string):
                    cocoEval.summarize()
                print_log('\n' + redirect_string.getvalue(), logger=logger)

                if classwise:  # Compute per-category AP
                    # Compute per-category AP
                    # from https://github.com/facebookresearch/detectron2/
                    precisions = cocoEval.eval['precision']
                    # precision: (iou, recall, cls, area range, max dets)
                    assert len(self.cat_ids) == precisions.shape[2]

                    results_per_category = []
                    for idx, catId in enumerate(self.cat_ids):
                        # area range index 0: all area ranges
                        # max dets index -1: typically 100 per image
                        nm = self.coco.loadCats(catId)[0]
                        precision = precisions[:, :, idx, 0, -1]
                        precision = precision[precision > -1]
                        if precision.size:
                            ap = np.mean(precision)
                        else:
                            ap = float('nan')
                        results_per_category.append(
                            (f'{nm["name"]}', f'{float(ap):0.3f}'))

                    num_columns = min(6, len(results_per_category) * 2)
                    results_flatten = list(
                        itertools.chain(*results_per_category))
                    headers = ['category', 'AP'] * (num_columns // 2)
                    results_2d = itertools.zip_longest(*[
                        results_flatten[i::num_columns]
                        for i in range(num_columns)
                    ])
                    table_data = [headers]
                    table_data += [result for result in results_2d]
                    table = AsciiTable(table_data)
                    print_log('\n' + table.table, logger=logger)

                if metric_items is None:
                    metric_items = [
                        'mAP', 'mAP_50', 'mAP_75', 'mAP_s', 'mAP_m', 'mAP_l'
                    ]

                for metric_item in metric_items:
                    key = f'{metric}_{metric_item}'
                    val = float(
                        f'{cocoEval.stats[coco_metric_names[metric_item]]:.3f}'
                    )
                    eval_results[key] = val
                ap = cocoEval.stats[:6]
                eval_results[f'{metric}_mAP_copypaste'] = (
                    f'{ap[0]:.3f} {ap[1]:.3f} {ap[2]:.3f} {ap[3]:.3f} '
                    f'{ap[4]:.3f} {ap[5]:.3f}')
        if tmp_dir is not None:
            tmp_dir.cleanup()
        return eval_results
# Out:
# Overwriting ./mmdetection/mmdet/datasets/coco.py

# %%
import re
#if you want to continue experiment from your last checkpoint, set the RESUME to True and paste the model path in model_path variable,
#don't forget to use the same architecture/parameters in above config

RESUME = False
if RESUME:
  model_path = "/log_mmdet/latest.pth"
  fname = '/mmdetection/configs/_base_/default_runtime.py'
  with open(fname) as f:
      s = f.read()
      s = re.sub('resume_from = None',
                'resume_from = {}'.format(model_path), s)
      s = re.sub(r'CLASSES = \(.*?\)',"EMPTY",s)

  with open(fname, 'w') as f:
      f.write(s)

# %%
print(config_fname)
# Out:
# 'mmdetection\\configs/htc/htc-without-semantic_r50_fpn_1x_coco.py'

# %%
# !python mmdetection/tools/train.py {config_fname} --work-dir ./log_mmdet
# Out:
# 11/15 18:22:04 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: win32
#     Python: 3.8.18 (default, Sep 11 2023, 13:39:12) [MSC v.1916 64 bit (AMD64)]
#     CUDA available: True
#     numpy_random_seed: 1329832558
#     GPU 0: NVIDIA GeForce RTX 3080
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.7
#     NVCC: Cuda compilation tools, release 11.7, V11.7.64
#     GCC: n/a
#     PyTorch: 1.13.0
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 199711
#   - MSVC 192829337
#   - Intel(R) Math Kernel Library Version 2020.0.2 Product Build 20200624 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.5
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /w /bigobj -DUSE_PTHREADPOOL -openmp:experimental -IC:/cb/pytorch_1000000000000/work/mkl/include -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.13.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.14.0
#     OpenCV: 4.8.1
#     MMEngine: 0.9.1
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1329832558
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 11/15 18:22:04 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = 'data/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(interval=1, type='CheckpointHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# model = dict(
#     backbone=dict(
#         depth=50,
#         frozen_stages=1,
#         init_cfg=dict(checkpoint='torchvision://resnet50', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNet'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=323,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=323,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=323,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         interleaved=True,
#         mask_head=[
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=323,
#                 num_convs=4,
#                 type='HTCMaskHead',
#                 with_conv_res=False),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=323,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=323,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#         ],
#         mask_info_flow=True,
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='HybridTaskCascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             mask_thr_binary=0.5,
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.001),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='HybridTaskCascade')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.0025, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=12,
#         gamma=0.1,
#         milestones=[
#             8,
#             11,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/new_ann.json',
#         backend_args=None,
#         data_prefix=dict(img='val/images/'),
#         data_root='data/',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='data/val/new_ann.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=22, type='EpochBasedTrainLoop', val_interval=1)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         ann_file='train/new_ann.json',
#         backend_args=None,
#         data_prefix=dict(img='train/images/'),
#         data_root='data/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/new_ann.json',
#         backend_args=None,
#         data_prefix=dict(img='val/images/'),
#         data_root='data/',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='data/val/new_ann.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './log_mmdet'
#
# 11/15 18:22:06 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 11/15 18:22:06 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=3.31s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# 11/15 18:22:12 - mmengine - INFO - load model from: torchvision://resnet50
# 11/15 18:22:12 - mmengine - INFO - Loads checkpoint by torchvision backend from path: torchvision://resnet50
# 11/15 18:22:12 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 11/15 18:22:12 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 11/15 18:22:12 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 11/15 18:22:12 - mmengine - INFO - Checkpoints will be saved to c:\Users\asiclab\Desktop\실전 딥러닝\project\log_mmdet.
# 11/15 18:22:29 - mmengine - INFO - Epoch(train)  [1][  50/2510]  lr: 2.4775e-04  eta: 5:25:06  time: 0.3536  data_time: 0.0869  memory: 4238  loss: 5.4628  loss_rpn_cls: 0.4928  loss_rpn_bbox: 0.0137  s0.loss_cls: 2.0599  s0.acc: 97.9492  s0.loss_bbox: 0.0167  s0.loss_mask: 0.6872  s1.loss_cls: 1.0563  s1.acc: 99.3164  s1.loss_bbox: 0.0049  s1.loss_mask: 0.3378  s2.loss_cls: 0.6051  s2.acc: 99.7070  s2.loss_bbox: 0.0006  s2.loss_mask: 0.1878
# 11/15 18:22:41 - mmengine - INFO - Epoch(train)  [1][ 100/2510]  lr: 4.9800e-04  eta: 4:32:00  time: 0.2386  data_time: 0.0027  memory: 3039  loss: 1.4370  loss_rpn_cls: 0.0417  loss_rpn_bbox: 0.0090  s0.loss_cls: 0.1514  s0.acc: 97.4609  s0.loss_bbox: 0.0580  s0.loss_mask: 0.6060  s1.loss_cls: 0.0546  s1.acc: 98.7305  s1.loss_bbox: 0.0210  s1.loss_mask: 0.3162  s2.loss_cls: 0.0180  s2.acc: 99.6094  s2.loss_bbox: 0.0030  s2.loss_mask: 0.1580
# 11/15 18:22:53 - mmengine - INFO - Epoch(train)  [1][ 150/2510]  lr: 7.4825e-04  eta: 4:12:50  time: 0.2342  data_time: 0.0026  memory: 4238  loss: 1.3308  loss_rpn_cls: 0.0217  loss_rpn_bbox: 0.0100  s0.loss_cls: 0.1252  s0.acc: 97.5586  s0.loss_bbox: 0.0588  s0.loss_mask: 0.5835  s1.loss_cls: 0.0478  s1.acc: 98.9258  s1.loss_bbox: 0.0205  s1.loss_mask: 0.2958  s2.loss_cls: 0.0147  s2.acc: 99.5117  s2.loss_bbox: 0.0027  s2.loss_mask: 0.1500
# 11/15 18:23:05 - mmengine - INFO - Epoch(train)  [1][ 200/2510]  lr: 9.9850e-04  eta: 4:03:36  time: 0.2362  data_time: 0.0027  memory: 3607  loss: 1.2553  loss_rpn_cls: 0.0150  loss_rpn_bbox: 0.0077  s0.loss_cls: 0.1102  s0.acc: 97.5586  s0.loss_bbox: 0.0534  s0.loss_mask: 0.5624  s1.loss_cls: 0.0344  s1.acc: 99.6094  s1.loss_bbox: 0.0186  s1.loss_mask: 0.2918  s2.loss_cls: 0.0122  s2.acc: 99.8047  s2.loss_bbox: 0.0025  s2.loss_mask: 0.1471
# 11/15 18:23:16 - mmengine - INFO - Epoch(train)  [1][ 250/2510]  lr: 1.2487e-03  eta: 3:57:16  time: 0.2323  data_time: 0.0026  memory: 4238  loss: 1.2613  loss_rpn_cls: 0.0157  loss_rpn_bbox: 0.0076  s0.loss_cls: 0.1136  s0.acc: 95.6055  s0.loss_bbox: 0.0565  s0.loss_mask: 0.5621  s1.loss_cls: 0.0355  s1.acc: 97.6562  s1.loss_bbox: 0.0229  s1.loss_mask: 0.2867  s2.loss_cls: 0.0125  s2.acc: 98.9258  s2.loss_bbox: 0.0035  s2.loss_mask: 0.1447
# 11/15 18:23:28 - mmengine - INFO - Epoch(train)  [1][ 300/2510]  lr: 1.4990e-03  eta: 3:53:03  time: 0.2328  data_time: 0.0025  memory: 3059  loss: 1.1862  loss_rpn_cls: 0.0143  loss_rpn_bbox: 0.0084  s0.loss_cls: 0.1100  s0.acc: 96.7773  s0.loss_bbox: 0.0577  s0.loss_mask: 0.5044  s1.loss_cls: 0.0359  s1.acc: 98.5352  s1.loss_bbox: 0.0279  s1.loss_mask: 0.2682  s2.loss_cls: 0.0132  s2.acc: 99.5117  s2.loss_bbox: 0.0049  s2.loss_mask: 0.1414
# 11/15 18:23:40 - mmengine - INFO - Epoch(train)  [1][ 350/2510]  lr: 1.7492e-03  eta: 3:49:57  time: 0.2325  data_time: 0.0027  memory: 3606  loss: 1.3492  loss_rpn_cls: 0.0219  loss_rpn_bbox: 0.0069  s0.loss_cls: 0.1386  s0.acc: 97.0703  s0.loss_bbox: 0.0682  s0.loss_mask: 0.5807  s1.loss_cls: 0.0434  s1.acc: 98.7305  s1.loss_bbox: 0.0255  s1.loss_mask: 0.2973  s2.loss_cls: 0.0154  s2.acc: 99.3164  s2.loss_bbox: 0.0043  s2.loss_mask: 0.1470
# 11/15 18:23:51 - mmengine - INFO - Epoch(train)  [1][ 400/2510]  lr: 1.9995e-03  eta: 3:47:47  time: 0.2342  data_time: 0.0028  memory: 3606  loss: 1.3335  loss_rpn_cls: 0.0155  loss_rpn_bbox: 0.0071  s0.loss_cls: 0.1179  s0.acc: 98.0469  s0.loss_bbox: 0.0561  s0.loss_mask: 0.6023  s1.loss_cls: 0.0360  s1.acc: 98.8281  s1.loss_bbox: 0.0208  s1.loss_mask: 0.3078  s2.loss_cls: 0.0131  s2.acc: 99.5117  s2.loss_bbox: 0.0036  s2.loss_mask: 0.1534
# 11/15 18:24:03 - mmengine - INFO - Epoch(train)  [1][ 450/2510]  lr: 2.2497e-03  eta: 3:46:52  time: 0.2424  data_time: 0.0028  memory: 3009  loss: 1.3649  loss_rpn_cls: 0.0151  loss_rpn_bbox: 0.0084  s0.loss_cls: 0.1344  s0.acc: 97.4609  s0.loss_bbox: 0.0623  s0.loss_mask: 0.6051  s1.loss_cls: 0.0426  s1.acc: 98.7305  s1.loss_bbox: 0.0264  s1.loss_mask: 0.3024  s2.loss_cls: 0.0129  s2.acc: 99.5117  s2.loss_bbox: 0.0045  s2.loss_mask: 0.1507
# 11/15 18:24:16 - mmengine - INFO - Epoch(train)  [1][ 500/2510]  lr: 2.5000e-03  eta: 3:46:40  time: 0.2486  data_time: 0.0028  memory: 4239  loss: 1.2665  loss_rpn_cls: 0.0113  loss_rpn_bbox: 0.0066  s0.loss_cls: 0.1258  s0.acc: 97.6562  s0.loss_bbox: 0.0705  s0.loss_mask: 0.5517  s1.loss_cls: 0.0422  s1.acc: 98.7305  s1.loss_bbox: 0.0314  s1.loss_mask: 0.2735  s2.loss_cls: 0.0117  s2.acc: 99.4141  s2.loss_bbox: 0.0056  s2.loss_mask: 0.1361
# 11/15 18:24:28 - mmengine - INFO - Epoch(train)  [1][ 550/2510]  lr: 2.5000e-03  eta: 3:45:41  time: 0.2393  data_time: 0.0028  memory: 4238  loss: 1.3872  loss_rpn_cls: 0.0174  loss_rpn_bbox: 0.0072  s0.loss_cls: 0.1456  s0.acc: 97.6562  s0.loss_bbox: 0.0653  s0.loss_mask: 0.6092  s1.loss_cls: 0.0445  s1.acc: 98.9258  s1.loss_bbox: 0.0285  s1.loss_mask: 0.3013  s2.loss_cls: 0.0124  s2.acc: 99.7070  s2.loss_bbox: 0.0047  s2.loss_mask: 0.1513
# 11/15 18:24:40 - mmengine - INFO - Epoch(train)  [1][ 600/2510]  lr: 2.5000e-03  eta: 3:44:53  time: 0.2398  data_time: 0.0026  memory: 4238  loss: 1.3136  loss_rpn_cls: 0.0117  loss_rpn_bbox: 0.0056  s0.loss_cls: 0.1245  s0.acc: 97.5586  s0.loss_bbox: 0.0676  s0.loss_mask: 0.5782  s1.loss_cls: 0.0416  s1.acc: 99.3164  s1.loss_bbox: 0.0323  s1.loss_mask: 0.2881  s2.loss_cls: 0.0110  s2.acc: 99.7070  s2.loss_bbox: 0.0059  s2.loss_mask: 0.1472
# 11/15 18:24:52 - mmengine - INFO - Epoch(train)  [1][ 650/2510]  lr: 2.5000e-03  eta: 3:43:46  time: 0.2340  data_time: 0.0025  memory: 3032  loss: 1.1190  loss_rpn_cls: 0.0158  loss_rpn_bbox: 0.0081  s0.loss_cls: 0.1107  s0.acc: 95.8984  s0.loss_bbox: 0.0563  s0.loss_mask: 0.4830  s1.loss_cls: 0.0340  s1.acc: 98.2422  s1.loss_bbox: 0.0244  s1.loss_mask: 0.2465  s2.loss_cls: 0.0100  s2.acc: 99.4141  s2.loss_bbox: 0.0046  s2.loss_mask: 0.1255
# 11/15 18:25:04 - mmengine - INFO - Epoch(train)  [1][ 700/2510]  lr: 2.5000e-03  eta: 3:43:22  time: 0.2431  data_time: 0.0027  memory: 4238  loss: 1.2588  loss_rpn_cls: 0.0147  loss_rpn_bbox: 0.0069  s0.loss_cls: 0.1283  s0.acc: 96.7773  s0.loss_bbox: 0.0669  s0.loss_mask: 0.5392  s1.loss_cls: 0.0444  s1.acc: 98.5352  s1.loss_bbox: 0.0325  s1.loss_mask: 0.2715  s2.loss_cls: 0.0126  s2.acc: 99.2188  s2.loss_bbox: 0.0061  s2.loss_mask: 0.1357
# 11/15 18:25:16 - mmengine - INFO - Epoch(train)  [1][ 750/2510]  lr: 2.5000e-03  eta: 3:42:48  time: 0.2399  data_time: 0.0028  memory: 4238  loss: 1.1866  loss_rpn_cls: 0.0155  loss_rpn_bbox: 0.0072  s0.loss_cls: 0.1223  s0.acc: 95.8984  s0.loss_bbox: 0.0678  s0.loss_mask: 0.5097  s1.loss_cls: 0.0372  s1.acc: 98.5352  s1.loss_bbox: 0.0299  s1.loss_mask: 0.2564  s2.loss_cls: 0.0106  s2.acc: 99.7070  s2.loss_bbox: 0.0058  s2.loss_mask: 0.1242
# 11/15 18:25:28 - mmengine - INFO - Epoch(train)  [1][ 800/2510]  lr: 2.5000e-03  eta: 3:42:35  time: 0.2453  data_time: 0.0028  memory: 4238  loss: 1.2393  loss_rpn_cls: 0.0163  loss_rpn_bbox: 0.0079  s0.loss_cls: 0.1454  s0.acc: 96.8750  s0.loss_bbox: 0.0744  s0.loss_mask: 0.5106  s1.loss_cls: 0.0478  s1.acc: 98.1445  s1.loss_bbox: 0.0374  s1.loss_mask: 0.2531  s2.loss_cls: 0.0130  s2.acc: 99.3164  s2.loss_bbox: 0.0076  s2.loss_mask: 0.1258
# 11/15 18:25:41 - mmengine - INFO - Epoch(train)  [1][ 850/2510]  lr: 2.5000e-03  eta: 3:42:40  time: 0.2508  data_time: 0.0027  memory: 4238  loss: 1.1506  loss_rpn_cls: 0.0101  loss_rpn_bbox: 0.0062  s0.loss_cls: 0.1367  s0.acc: 98.1445  s0.loss_bbox: 0.0725  s0.loss_mask: 0.4644  s1.loss_cls: 0.0453  s1.acc: 98.1445  s1.loss_bbox: 0.0371  s1.loss_mask: 0.2339  s2.loss_cls: 0.0137  s2.acc: 99.1211  s2.loss_bbox: 0.0080  s2.loss_mask: 0.1228
# 11/15 18:25:53 - mmengine - INFO - Epoch(train)  [1][ 900/2510]  lr: 2.5000e-03  eta: 3:43:01  time: 0.2567  data_time: 0.0030  memory: 4238  loss: 1.0721  loss_rpn_cls: 0.0177  loss_rpn_bbox: 0.0067  s0.loss_cls: 0.1089  s0.acc: 97.2656  s0.loss_bbox: 0.0580  s0.loss_mask: 0.4495  s1.loss_cls: 0.0380  s1.acc: 98.2422  s1.loss_bbox: 0.0296  s1.loss_mask: 0.2308  s2.loss_cls: 0.0122  s2.acc: 99.0234  s2.loss_bbox: 0.0062  s2.loss_mask: 0.1144
# 11/15 18:26:06 - mmengine - INFO - Epoch(train)  [1][ 950/2510]  lr: 2.5000e-03  eta: 3:43:18  time: 0.2567  data_time: 0.0029  memory: 3099  loss: 1.1674  loss_rpn_cls: 0.0153  loss_rpn_bbox: 0.0078  s0.loss_cls: 0.1200  s0.acc: 97.7539  s0.loss_bbox: 0.0554  s0.loss_mask: 0.4896  s1.loss_cls: 0.0455  s1.acc: 98.4375  s1.loss_bbox: 0.0346  s1.loss_mask: 0.2517  s2.loss_cls: 0.0135  s2.acc: 99.3164  s2.loss_bbox: 0.0080  s2.loss_mask: 0.1261
# 11/15 18:26:21 - mmengine - INFO - Exp name: htc-without-semantic_r50_fpn_1x_coco_20231115_182203
# 11/15 18:26:21 - mmengine - INFO - Epoch(train)  [1][1000/2510]  lr: 2.5000e-03  eta: 3:44:55  time: 0.2873  data_time: 0.0033  memory: 3606  loss: 1.1696  loss_rpn_cls: 0.0128  loss_rpn_bbox: 0.0060  s0.loss_cls: 0.1117  s0.acc: 97.8516  s0.loss_bbox: 0.0541  s0.loss_mask: 0.5124  s1.loss_cls: 0.0389  s1.acc: 98.7305  s1.loss_bbox: 0.0288  s1.loss_mask: 0.2579  s2.loss_cls: 0.0112  s2.acc: 99.5117  s2.loss_bbox: 0.0066  s2.loss_mask: 0.1291
# 11/15 18:26:36 - mmengine - INFO - Epoch(train)  [1][1050/2510]  lr: 2.5000e-03  eta: 3:47:14  time: 0.3076  data_time: 0.0041  memory: 4238  loss: 1.1313  loss_rpn_cls: 0.0122  loss_rpn_bbox: 0.0070  s0.loss_cls: 0.1270  s0.acc: 96.9727  s0.loss_bbox: 0.0669  s0.loss_mask: 0.4738  s1.loss_cls: 0.0415  s1.acc: 98.1445  s1.loss_bbox: 0.0332  s1.loss_mask: 0.2333  s2.loss_cls: 0.0125  s2.acc: 99.3164  s2.loss_bbox: 0.0073  s2.loss_mask: 0.1166
# 11/15 18:26:51 - mmengine - INFO - Epoch(train)  [1][1100/2510]  lr: 2.5000e-03  eta: 3:49:07  time: 0.3026  data_time: 0.0041  memory: 3125  loss: 1.0715  loss_rpn_cls: 0.0121  loss_rpn_bbox: 0.0060  s0.loss_cls: 0.1219  s0.acc: 95.7031  s0.loss_bbox: 0.0652  s0.loss_mask: 0.4419  s1.loss_cls: 0.0398  s1.acc: 97.8516  s1.loss_bbox: 0.0339  s1.loss_mask: 0.2205  s2.loss_cls: 0.0114  s2.acc: 99.4141  s2.loss_bbox: 0.0080  s2.loss_mask: 0.1109
# 11/15 18:27:06 - mmengine - INFO - Epoch(train)  [1][1150/2510]  lr: 2.5000e-03  eta: 3:50:42  time: 0.2999  data_time: 0.0042  memory: 3763  loss: 1.1199  loss_rpn_cls: 0.0140  loss_rpn_bbox: 0.0066  s0.loss_cls: 0.1156  s0.acc: 97.8516  s0.loss_bbox: 0.0608  s0.loss_mask: 0.4757  s1.loss_cls: 0.0411  s1.acc: 98.5352  s1.loss_bbox: 0.0334  s1.loss_mask: 0.2364  s2.loss_cls: 0.0114  s2.acc: 98.8281  s2.loss_bbox: 0.0074  s2.loss_mask: 0.1175
# 11/15 18:27:19 - mmengine - INFO - Epoch(train)  [1][1200/2510]  lr: 2.5000e-03  eta: 3:50:27  time: 0.2551  data_time: 0.0028  memory: 4238  loss: 1.0559  loss_rpn_cls: 0.0138  loss_rpn_bbox: 0.0063  s0.loss_cls: 0.1109  s0.acc: 97.5586  s0.loss_bbox: 0.0610  s0.loss_mask: 0.4381  s1.loss_cls: 0.0386  s1.acc: 97.9492  s1.loss_bbox: 0.0325  s1.loss_mask: 0.2235  s2.loss_cls: 0.0116  s2.acc: 99.5117  s2.loss_bbox: 0.0078  s2.loss_mask: 0.1116
# 11/15 18:27:32 - mmengine - INFO - Epoch(train)  [1][1250/2510]  lr: 2.5000e-03  eta: 3:50:09  time: 0.2533  data_time: 0.0029  memory: 3607  loss: 1.0873  loss_rpn_cls: 0.0181  loss_rpn_bbox: 0.0066  s0.loss_cls: 0.1043  s0.acc: 97.9492  s0.loss_bbox: 0.0559  s0.loss_mask: 0.4690  s1.loss_cls: 0.0362  s1.acc: 98.6328  s1.loss_bbox: 0.0282  s1.loss_mask: 0.2369  s2.loss_cls: 0.0104  s2.acc: 99.4141  s2.loss_bbox: 0.0063  s2.loss_mask: 0.1155
# 11/15 18:27:44 - mmengine - INFO - Epoch(train)  [1][1300/2510]  lr: 2.5000e-03  eta: 3:49:44  time: 0.2503  data_time: 0.0028  memory: 3101  loss: 0.9765  loss_rpn_cls: 0.0139  loss_rpn_bbox: 0.0075  s0.loss_cls: 0.1059  s0.acc: 98.3398  s0.loss_bbox: 0.0563  s0.loss_mask: 0.3985  s1.loss_cls: 0.0379  s1.acc: 99.1211  s1.loss_bbox: 0.0308  s1.loss_mask: 0.2030  s2.loss_cls: 0.0116  s2.acc: 99.5117  s2.loss_bbox: 0.0076  s2.loss_mask: 0.1035
# 11/15 18:27:57 - mmengine - INFO - Epoch(train)  [1][1350/2510]  lr: 2.5000e-03  eta: 3:49:31  time: 0.2554  data_time: 0.0029  memory: 4238  loss: 0.9601  loss_rpn_cls: 0.0121  loss_rpn_bbox: 0.0042  s0.loss_cls: 0.1045  s0.acc: 97.1680  s0.loss_bbox: 0.0558  s0.loss_mask: 0.4003  s1.loss_cls: 0.0379  s1.acc: 98.5352  s1.loss_bbox: 0.0325  s1.loss_mask: 0.1943  s2.loss_cls: 0.0121  s2.acc: 99.2188  s2.loss_bbox: 0.0085  s2.loss_mask: 0.0980
# 11/15 18:28:10 - mmengine - INFO - Epoch(train)  [1][1400/2510]  lr: 2.5000e-03  eta: 3:49:18  time: 0.2555  data_time: 0.0030  memory: 3142  loss: 0.9803  loss_rpn_cls: 0.0136  loss_rpn_bbox: 0.0055  s0.loss_cls: 0.1132  s0.acc: 96.5820  s0.loss_bbox: 0.0634  s0.loss_mask: 0.3949  s1.loss_cls: 0.0408  s1.acc: 96.8750  s1.loss_bbox: 0.0352  s1.loss_mask: 0.1982  s2.loss_cls: 0.0119  s2.acc: 98.9258  s2.loss_bbox: 0.0086  s2.loss_mask: 0.0949
# 11/15 18:28:23 - mmengine - INFO - Epoch(train)  [1][1450/2510]  lr: 2.5000e-03  eta: 3:49:13  time: 0.2599  data_time: 0.0031  memory: 4238  loss: 1.0417  loss_rpn_cls: 0.0134  loss_rpn_bbox: 0.0055  s0.loss_cls: 0.1042  s0.acc: 95.4102  s0.loss_bbox: 0.0575  s0.loss_mask: 0.4336  s1.loss_cls: 0.0407  s1.acc: 97.9492  s1.loss_bbox: 0.0354  s1.loss_mask: 0.2236  s2.loss_cls: 0.0125  s2.acc: 99.5117  s2.loss_bbox: 0.0087  s2.loss_mask: 0.1065
# 11/15 18:28:36 - mmengine - INFO - Epoch(train)  [1][1500/2510]  lr: 2.5000e-03  eta: 3:49:07  time: 0.2593  data_time: 0.0029  memory: 3247  loss: 1.0267  loss_rpn_cls: 0.0129  loss_rpn_bbox: 0.0059  s0.loss_cls: 0.1071  s0.acc: 97.9492  s0.loss_bbox: 0.0595  s0.loss_mask: 0.4304  s1.loss_cls: 0.0383  s1.acc: 99.3164  s1.loss_bbox: 0.0313  s1.loss_mask: 0.2131  s2.loss_cls: 0.0118  s2.acc: 99.3164  s2.loss_bbox: 0.0085  s2.loss_mask: 0.1077
# 11/15 18:28:48 - mmengine - INFO - Epoch(train)  [1][1550/2510]  lr: 2.5000e-03  eta: 3:48:53  time: 0.2553  data_time: 0.0029  memory: 4238  loss: 1.0132  loss_rpn_cls: 0.0129  loss_rpn_bbox: 0.0064  s0.loss_cls: 0.1176  s0.acc: 95.1172  s0.loss_bbox: 0.0623  s0.loss_mask: 0.4171  s1.loss_cls: 0.0394  s1.acc: 97.4609  s1.loss_bbox: 0.0330  s1.loss_mask: 0.2060  s2.loss_cls: 0.0114  s2.acc: 98.4375  s2.loss_bbox: 0.0079  s2.loss_mask: 0.0992
# 11/15 18:29:01 - mmengine - INFO - Epoch(train)  [1][1600/2510]  lr: 2.5000e-03  eta: 3:48:48  time: 0.2609  data_time: 0.0030  memory: 4238  loss: 1.0739  loss_rpn_cls: 0.0137  loss_rpn_bbox: 0.0068  s0.loss_cls: 0.1192  s0.acc: 97.7539  s0.loss_bbox: 0.0650  s0.loss_mask: 0.4385  s1.loss_cls: 0.0417  s1.acc: 98.0469  s1.loss_bbox: 0.0383  s1.loss_mask: 0.2185  s2.loss_cls: 0.0126  s2.acc: 98.3398  s2.loss_bbox: 0.0105  s2.loss_mask: 0.1091
# 11/15 18:29:14 - mmengine - INFO - Epoch(train)  [1][1650/2510]  lr: 2.5000e-03  eta: 3:48:43  time: 0.2607  data_time: 0.0030  memory: 4238  loss: 1.0233  loss_rpn_cls: 0.0134  loss_rpn_bbox: 0.0060  s0.loss_cls: 0.1082  s0.acc: 97.7539  s0.loss_bbox: 0.0634  s0.loss_mask: 0.4195  s1.loss_cls: 0.0388  s1.acc: 98.7305  s1.loss_bbox: 0.0361  s1.loss_mask: 0.2116  s2.loss_cls: 0.0119  s2.acc: 99.0234  s2.loss_bbox: 0.0091  s2.loss_mask: 0.1052
# 11/15 18:29:27 - mmengine - INFO - Epoch(train)  [1][1700/2510]  lr: 2.5000e-03  eta: 3:48:38  time: 0.2614  data_time: 0.0030  memory: 3606  loss: 0.8588  loss_rpn_cls: 0.0117  loss_rpn_bbox: 0.0050  s0.loss_cls: 0.1054  s0.acc: 97.7539  s0.loss_bbox: 0.0626  s0.loss_mask: 0.3294  s1.loss_cls: 0.0411  s1.acc: 97.8516  s1.loss_bbox: 0.0381  s1.loss_mask: 0.1629  s2.loss_cls: 0.0135  s2.acc: 98.1445  s2.loss_bbox: 0.0114  s2.loss_mask: 0.0777
# 11/15 18:29:40 - mmengine - INFO - Epoch(train)  [1][1750/2510]  lr: 2.5000e-03  eta: 3:48:22  time: 0.2538  data_time: 0.0029  memory: 3606  loss: 0.9795  loss_rpn_cls: 0.0132  loss_rpn_bbox: 0.0054  s0.loss_cls: 0.0985  s0.acc: 96.6797  s0.loss_bbox: 0.0593  s0.loss_mask: 0.4214  s1.loss_cls: 0.0333  s1.acc: 97.5586  s1.loss_bbox: 0.0303  s1.loss_mask: 0.2031  s2.loss_cls: 0.0108  s2.acc: 98.8281  s2.loss_bbox: 0.0079  s2.loss_mask: 0.0964
# 11/15 18:29:53 - mmengine - INFO - Epoch(train)  [1][1800/2510]  lr: 2.5000e-03  eta: 3:48:09  time: 0.2564  data_time: 0.0029  memory: 3207  loss: 0.8983  loss_rpn_cls: 0.0115  loss_rpn_bbox: 0.0059  s0.loss_cls: 0.1053  s0.acc: 96.6797  s0.loss_bbox: 0.0635  s0.loss_mask: 0.3573  s1.loss_cls: 0.0373  s1.acc: 98.3398  s1.loss_bbox: 0.0383  s1.loss_mask: 0.1705  s2.loss_cls: 0.0128  s2.acc: 97.9492  s2.loss_bbox: 0.0117  s2.loss_mask: 0.0840
# 11/15 18:30:06 - mmengine - INFO - Epoch(train)  [1][1850/2510]  lr: 2.5000e-03  eta: 3:47:54  time: 0.2547  data_time: 0.0029  memory: 3179  loss: 0.9264  loss_rpn_cls: 0.0138  loss_rpn_bbox: 0.0055  s0.loss_cls: 0.1005  s0.acc: 98.3398  s0.loss_bbox: 0.0599  s0.loss_mask: 0.3641  s1.loss_cls: 0.0376  s1.acc: 98.9258  s1.loss_bbox: 0.0365  s1.loss_mask: 0.1924  s2.loss_cls: 0.0118  s2.acc: 98.6328  s2.loss_bbox: 0.0094  s2.loss_mask: 0.0951
# 11/15 18:30:18 - mmengine - INFO - Epoch(train)  [1][1900/2510]  lr: 2.5000e-03  eta: 3:47:39  time: 0.2547  data_time: 0.0030  memory: 4238  loss: 0.9604  loss_rpn_cls: 0.0152  loss_rpn_bbox: 0.0067  s0.loss_cls: 0.1011  s0.acc: 96.9727  s0.loss_bbox: 0.0564  s0.loss_mask: 0.4045  s1.loss_cls: 0.0351  s1.acc: 99.0234  s1.loss_bbox: 0.0309  s1.loss_mask: 0.1946  s2.loss_cls: 0.0105  s2.acc: 99.5117  s2.loss_bbox: 0.0068  s2.loss_mask: 0.0986
# 11/15 18:30:31 - mmengine - INFO - Epoch(train)  [1][1950/2510]  lr: 2.5000e-03  eta: 3:47:23  time: 0.2534  data_time: 0.0030  memory: 3606  loss: 1.0396  loss_rpn_cls: 0.0108  loss_rpn_bbox: 0.0056  s0.loss_cls: 0.1151  s0.acc: 96.9727  s0.loss_bbox: 0.0683  s0.loss_mask: 0.4263  s1.loss_cls: 0.0411  s1.acc: 97.6562  s1.loss_bbox: 0.0371  s1.loss_mask: 0.2107  s2.loss_cls: 0.0119  s2.acc: 98.9258  s2.loss_bbox: 0.0089  s2.loss_mask: 0.1038
# 11/15 18:30:44 - mmengine - INFO - Exp name: htc-without-semantic_r50_fpn_1x_coco_20231115_182203
# 11/15 18:30:44 - mmengine - INFO - Epoch(train)  [1][2000/2510]  lr: 2.5000e-03  eta: 3:47:09  time: 0.2556  data_time: 0.0031  memory: 3606  loss: 0.9630  loss_rpn_cls: 0.0114  loss_rpn_bbox: 0.0048  s0.loss_cls: 0.0921  s0.acc: 97.8516  s0.loss_bbox: 0.0606  s0.loss_mask: 0.4059  s1.loss_cls: 0.0330  s1.acc: 97.3633  s1.loss_bbox: 0.0360  s1.loss_mask: 0.1988  s2.loss_cls: 0.0105  s2.acc: 98.7305  s2.loss_bbox: 0.0094  s2.loss_mask: 0.1005
# 11/15 18:30:57 - mmengine - INFO - Epoch(train)  [1][2050/2510]  lr: 2.5000e-03  eta: 3:46:56  time: 0.2558  data_time: 0.0027  memory: 4238  loss: 0.9118  loss_rpn_cls: 0.0164  loss_rpn_bbox: 0.0064  s0.loss_cls: 0.0874  s0.acc: 98.4375  s0.loss_bbox: 0.0547  s0.loss_mask: 0.3767  s1.loss_cls: 0.0330  s1.acc: 98.5352  s1.loss_bbox: 0.0327  s1.loss_mask: 0.1899  s2.loss_cls: 0.0107  s2.acc: 99.3164  s2.loss_bbox: 0.0086  s2.loss_mask: 0.0953
# 11/15 18:31:09 - mmengine - INFO - Epoch(train)  [1][2100/2510]  lr: 2.5000e-03  eta: 3:46:42  time: 0.2553  data_time: 0.0028  memory: 3606  loss: 0.9263  loss_rpn_cls: 0.0134  loss_rpn_bbox: 0.0059  s0.loss_cls: 0.1011  s0.acc: 98.0469  s0.loss_bbox: 0.0576  s0.loss_mask: 0.3706  s1.loss_cls: 0.0371  s1.acc: 98.4375  s1.loss_bbox: 0.0353  s1.loss_mask: 0.1868  s2.loss_cls: 0.0115  s2.acc: 99.1211  s2.loss_bbox: 0.0092  s2.loss_mask: 0.0976
# 11/15 18:31:22 - mmengine - INFO - Epoch(train)  [1][2150/2510]  lr: 2.5000e-03  eta: 3:46:25  time: 0.2527  data_time: 0.0028  memory: 4238  loss: 0.8596  loss_rpn_cls: 0.0157  loss_rpn_bbox: 0.0069  s0.loss_cls: 0.0926  s0.acc: 96.8750  s0.loss_bbox: 0.0557  s0.loss_mask: 0.3465  s1.loss_cls: 0.0340  s1.acc: 97.5586  s1.loss_bbox: 0.0321  s1.loss_mask: 0.1715  s2.loss_cls: 0.0110  s2.acc: 99.2188  s2.loss_bbox: 0.0097  s2.loss_mask: 0.0839
# 11/15 18:31:35 - mmengine - INFO - Epoch(train)  [1][2200/2510]  lr: 2.5000e-03  eta: 3:46:17  time: 0.2599  data_time: 0.0030  memory: 3606  loss: 0.9512  loss_rpn_cls: 0.0135  loss_rpn_bbox: 0.0057  s0.loss_cls: 0.0989  s0.acc: 96.9727  s0.loss_bbox: 0.0548  s0.loss_mask: 0.3990  s1.loss_cls: 0.0354  s1.acc: 98.0469  s1.loss_bbox: 0.0324  s1.loss_mask: 0.1967  s2.loss_cls: 0.0113  s2.acc: 99.1211  s2.loss_bbox: 0.0090  s2.loss_mask: 0.0946
# 11/15 18:31:48 - mmengine - INFO - Epoch(train)  [1][2250/2510]  lr: 2.5000e-03  eta: 3:46:13  time: 0.2634  data_time: 0.0028  memory: 3125  loss: 0.9179  loss_rpn_cls: 0.0118  loss_rpn_bbox: 0.0071  s0.loss_cls: 0.0984  s0.acc: 98.5352  s0.loss_bbox: 0.0559  s0.loss_mask: 0.3704  s1.loss_cls: 0.0360  s1.acc: 98.6328  s1.loss_bbox: 0.0345  s1.loss_mask: 0.1905  s2.loss_cls: 0.0111  s2.acc: 98.9258  s2.loss_bbox: 0.0095  s2.loss_mask: 0.0927
# 11/15 18:32:01 - mmengine - INFO - Epoch(train)  [1][2300/2510]  lr: 2.5000e-03  eta: 3:45:53  time: 0.2498  data_time: 0.0029  memory: 3606  loss: 0.8315  loss_rpn_cls: 0.0151  loss_rpn_bbox: 0.0075  s0.loss_cls: 0.0898  s0.acc: 97.7539  s0.loss_bbox: 0.0540  s0.loss_mask: 0.3299  s1.loss_cls: 0.0330  s1.acc: 97.0703  s1.loss_bbox: 0.0298  s1.loss_mask: 0.1701  s2.loss_cls: 0.0106  s2.acc: 98.3398  s2.loss_bbox: 0.0079  s2.loss_mask: 0.0838
# 11/15 18:32:13 - mmengine - INFO - Epoch(train)  [1][2350/2510]  lr: 2.5000e-03  eta: 3:45:37  time: 0.2539  data_time: 0.0027  memory: 3607  loss: 0.9232  loss_rpn_cls: 0.0128  loss_rpn_bbox: 0.0054  s0.loss_cls: 0.0952  s0.acc: 98.0469  s0.loss_bbox: 0.0585  s0.loss_mask: 0.3812  s1.loss_cls: 0.0368  s1.acc: 98.9258  s1.loss_bbox: 0.0371  s1.loss_mask: 0.1839  s2.loss_cls: 0.0118  s2.acc: 99.2188  s2.loss_bbox: 0.0102  s2.loss_mask: 0.0904
# 11/15 18:32:26 - mmengine - INFO - Epoch(train)  [1][2400/2510]  lr: 2.5000e-03  eta: 3:45:29  time: 0.2603  data_time: 0.0028  memory: 3198  loss: 0.9232  loss_rpn_cls: 0.0144  loss_rpn_bbox: 0.0091  s0.loss_cls: 0.0961  s0.acc: 97.2656  s0.loss_bbox: 0.0582  s0.loss_mask: 0.3766  s1.loss_cls: 0.0353  s1.acc: 97.6562  s1.loss_bbox: 0.0333  s1.loss_mask: 0.1871  s2.loss_cls: 0.0110  s2.acc: 98.8281  s2.loss_bbox: 0.0097  s2.loss_mask: 0.0924
# 11/15 18:32:39 - mmengine - INFO - Epoch(train)  [1][2450/2510]  lr: 2.5000e-03  eta: 3:45:14  time: 0.2536  data_time: 0.0028  memory: 3607  loss: 0.9009  loss_rpn_cls: 0.0144  loss_rpn_bbox: 0.0069  s0.loss_cls: 0.0994  s0.acc: 96.9727  s0.loss_bbox: 0.0582  s0.loss_mask: 0.3643  s1.loss_cls: 0.0368  s1.acc: 98.2422  s1.loss_bbox: 0.0336  s1.loss_mask: 0.1790  s2.loss_cls: 0.0112  s2.acc: 99.5117  s2.loss_bbox: 0.0084  s2.loss_mask: 0.0885
# 11/15 18:32:52 - mmengine - INFO - Epoch(train)  [1][2500/2510]  lr: 2.5000e-03  eta: 3:45:01  time: 0.2559  data_time: 0.0027  memory: 4238  loss: 0.9034  loss_rpn_cls: 0.0138  loss_rpn_bbox: 0.0062  s0.loss_cls: 0.0851  s0.acc: 97.8516  s0.loss_bbox: 0.0537  s0.loss_mask: 0.3682  s1.loss_cls: 0.0347  s1.acc: 98.8281  s1.loss_bbox: 0.0355  s1.loss_mask: 0.1905  s2.loss_cls: 0.0115  s2.acc: 99.8047  s2.loss_bbox: 0.0096  s2.loss_mask: 0.0946
# 11/15 18:32:54 - mmengine - INFO - Exp name: htc-without-semantic_r50_fpn_1x_coco_20231115_182203
# 11/15 18:32:54 - mmengine - INFO - Saving checkpoint at 1 epochs
# 11/15 18:33:14 - mmengine - INFO - Epoch(val)  [1][ 50/946]    eta: 0:05:07  time: 0.3432  data_time: 0.0805  memory: 3147
# 11/15 18:33:23 - mmengine - INFO - Epoch(val)  [1][100/946]    eta: 0:03:42  time: 0.1821  data_time: 0.0008  memory: 2446
# 11/15 18:33:36 - mmengine - INFO - Epoch(val)  [1][150/946]    eta: 0:03:29  time: 0.2644  data_time: 0.0009  memory: 2863
# 11/15 18:33:56 - mmengine - INFO - Epoch(val)  [1][200/946]    eta: 0:03:40  time: 0.3952  data_time: 0.0008  memory: 4263
# 11/15 18:34:14 - mmengine - INFO - Epoch(val)  [1][250/946]    eta: 0:03:34  time: 0.3534  data_time: 0.0009  memory: 3350
# 11/15 18:34:22 - mmengine - INFO - Epoch(val)  [1][300/946]    eta: 0:03:03  time: 0.1686  data_time: 0.0009  memory: 2661
# 11/15 18:34:34 - mmengine - INFO - Epoch(val)  [1][350/946]    eta: 0:02:45  time: 0.2334  data_time: 0.0009  memory: 2688
# 11/15 18:34:49 - mmengine - INFO - Epoch(val)  [1][400/946]    eta: 0:02:32  time: 0.3012  data_time: 0.0009  memory: 2688
# 11/15 18:35:02 - mmengine - INFO - Epoch(val)  [1][450/946]    eta: 0:02:17  time: 0.2571  data_time: 0.0009  memory: 3350
# 11/15 18:35:20 - mmengine - INFO - Epoch(val)  [1][500/946]    eta: 0:02:07  time: 0.3595  data_time: 0.0009  memory: 2849
# 11/15 18:35:39 - mmengine - INFO - Epoch(val)  [1][550/946]    eta: 0:01:56  time: 0.3890  data_time: 0.0010  memory: 2728
# 11/15 18:35:51 - mmengine - INFO - Epoch(val)  [1][600/946]    eta: 0:01:40  time: 0.2309  data_time: 0.0009  memory: 2630
# 11/15 18:36:03 - mmengine - INFO - Epoch(val)  [1][650/946]    eta: 0:01:24  time: 0.2393  data_time: 0.0009  memory: 3279
# 11/15 18:36:18 - mmengine - INFO - Epoch(val)  [1][700/946]    eta: 0:01:10  time: 0.3062  data_time: 0.0011  memory: 3350
# 11/15 18:36:31 - mmengine - INFO - Epoch(val)  [1][750/946]    eta: 0:00:56  time: 0.2668  data_time: 0.0008  memory: 2731
# 11/15 18:36:44 - mmengine - INFO - Epoch(val)  [1][800/946]    eta: 0:00:41  time: 0.2483  data_time: 0.0009  memory: 2696
# 11/15 18:37:00 - mmengine - INFO - Epoch(val)  [1][850/946]    eta: 0:00:27  time: 0.3260  data_time: 0.0008  memory: 4263
# 11/15 18:37:16 - mmengine - INFO - Epoch(val)  [1][900/946]    eta: 0:00:13  time: 0.3269  data_time: 0.0009  memory: 3350
# 11/15 18:37:30 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.16s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.79s).
# Accumulating evaluation results...
# DONE (t=0.97s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.041
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.102
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.148
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.389
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.389
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.389
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.147
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.410
# 11/15 18:37:32 - mmengine - INFO - bbox_mAP_copypaste: 0.041 0.102 0.009 0.000 0.148 0.044
# 11/15 18:37:32 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.75s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=1.36s).
# Accumulating evaluation results...
# DONE (t=0.96s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.063
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.005
# ...
# 11/16 00:16:46 - mmengine - INFO - Epoch(train) [22][1450/2510]  lr: 2.5000e-05  eta: 0:04:56  time: 0.2848  data_time: 0.0030  memory: 3694  loss: 0.4784  loss_rpn_cls: 0.0092  loss_rpn_bbox: 0.0048  s0.loss_cls: 0.0624  s0.acc: 97.9492  s0.loss_bbox: 0.0416  s0.loss_mask: 0.1522  s1.loss_cls: 0.0289  s1.acc: 97.7539  s1.loss_bbox: 0.0376  s1.loss_mask: 0.0751  s2.loss_cls: 0.0123  s2.acc: 97.7539  s2.loss_bbox: 0.0171  s2.loss_mask: 0.0372
# 11/16 00:17:01 - mmengine - INFO - Epoch(train) [22][1500/2510]  lr: 2.5000e-05  eta: 0:04:42  time: 0.2911  data_time: 0.0029  memory: 4380  loss: 0.4752  loss_rpn_cls: 0.0094  loss_rpn_bbox: 0.0047  s0.loss_cls: 0.0591  s0.acc: 98.9258  s0.loss_bbox: 0.0417  s0.loss_mask: 0.1533  s1.loss_cls: 0.0280  s1.acc: 99.4141  s1.loss_bbox: 0.0393  s1.loss_mask: 0.0728  s2.loss_cls: 0.0126  s2.acc: 99.9023  s2.loss_bbox: 0.0187  s2.loss_mask: 0.0357
# 11/16 00:17:15 - mmengine - INFO - Epoch(train) [22][1550/2510]  lr: 2.5000e-05  eta: 0:04:28  time: 0.2852  data_time: 0.0029  memory: 3878  loss: 0.4618  loss_rpn_cls: 0.0071  loss_rpn_bbox: 0.0041  s0.loss_cls: 0.0666  s0.acc: 97.7539  s0.loss_bbox: 0.0433  s0.loss_mask: 0.1399  s1.loss_cls: 0.0316  s1.acc: 98.2422  s1.loss_bbox: 0.0392  s1.loss_mask: 0.0677  s2.loss_cls: 0.0125  s2.acc: 98.7305  s2.loss_bbox: 0.0170  s2.loss_mask: 0.0328
# 11/16 00:17:29 - mmengine - INFO - Epoch(train) [22][1600/2510]  lr: 2.5000e-05  eta: 0:04:14  time: 0.2860  data_time: 0.0029  memory: 4050  loss: 0.4583  loss_rpn_cls: 0.0070  loss_rpn_bbox: 0.0039  s0.loss_cls: 0.0590  s0.acc: 99.3164  s0.loss_bbox: 0.0433  s0.loss_mask: 0.1413  s1.loss_cls: 0.0287  s1.acc: 98.5352  s1.loss_bbox: 0.0414  s1.loss_mask: 0.0687  s2.loss_cls: 0.0121  s2.acc: 98.4375  s2.loss_bbox: 0.0193  s2.loss_mask: 0.0336
# 11/16 00:17:44 - mmengine - INFO - Epoch(train) [22][1650/2510]  lr: 2.5000e-05  eta: 0:04:00  time: 0.2920  data_time: 0.0030  memory: 4238  loss: 0.4687  loss_rpn_cls: 0.0102  loss_rpn_bbox: 0.0047  s0.loss_cls: 0.0623  s0.acc: 98.2422  s0.loss_bbox: 0.0401  s0.loss_mask: 0.1495  s1.loss_cls: 0.0280  s1.acc: 96.9727  s1.loss_bbox: 0.0338  s1.loss_mask: 0.0750  s2.loss_cls: 0.0112  s2.acc: 97.8516  s2.loss_bbox: 0.0170  s2.loss_mask: 0.0369
# 11/16 00:17:59 - mmengine - INFO - Epoch(train) [22][1700/2510]  lr: 2.5000e-05  eta: 0:03:46  time: 0.2894  data_time: 0.0029  memory: 3735  loss: 0.4491  loss_rpn_cls: 0.0101  loss_rpn_bbox: 0.0043  s0.loss_cls: 0.0593  s0.acc: 98.7305  s0.loss_bbox: 0.0425  s0.loss_mask: 0.1337  s1.loss_cls: 0.0269  s1.acc: 99.0234  s1.loss_bbox: 0.0393  s1.loss_mask: 0.0670  s2.loss_cls: 0.0114  s2.acc: 99.2188  s2.loss_bbox: 0.0201  s2.loss_mask: 0.0344
# 11/16 00:18:13 - mmengine - INFO - Epoch(train) [22][1750/2510]  lr: 2.5000e-05  eta: 0:03:32  time: 0.2833  data_time: 0.0031  memory: 3628  loss: 0.4618  loss_rpn_cls: 0.0095  loss_rpn_bbox: 0.0039  s0.loss_cls: 0.0653  s0.acc: 98.5352  s0.loss_bbox: 0.0457  s0.loss_mask: 0.1375  s1.loss_cls: 0.0302  s1.acc: 99.4141  s1.loss_bbox: 0.0404  s1.loss_mask: 0.0657  s2.loss_cls: 0.0126  s2.acc: 98.9258  s2.loss_bbox: 0.0175  s2.loss_mask: 0.0336
# 11/16 00:18:27 - mmengine - INFO - Epoch(train) [22][1800/2510]  lr: 2.5000e-05  eta: 0:03:18  time: 0.2865  data_time: 0.0030  memory: 3791  loss: 0.5307  loss_rpn_cls: 0.0083  loss_rpn_bbox: 0.0046  s0.loss_cls: 0.0677  s0.acc: 97.0703  s0.loss_bbox: 0.0418  s0.loss_mask: 0.1721  s1.loss_cls: 0.0325  s1.acc: 96.2891  s1.loss_bbox: 0.0410  s1.loss_mask: 0.0871  s2.loss_cls: 0.0135  s2.acc: 96.6797  s2.loss_bbox: 0.0181  s2.loss_mask: 0.0440
# 11/16 00:18:41 - mmengine - INFO - Epoch(train) [22][1850/2510]  lr: 2.5000e-05  eta: 0:03:04  time: 0.2895  data_time: 0.0032  memory: 4254  loss: 0.4795  loss_rpn_cls: 0.0091  loss_rpn_bbox: 0.0050  s0.loss_cls: 0.0684  s0.acc: 99.3164  s0.loss_bbox: 0.0439  s0.loss_mask: 0.1432  s1.loss_cls: 0.0315  s1.acc: 99.3164  s1.loss_bbox: 0.0384  s1.loss_mask: 0.0722  s2.loss_cls: 0.0137  s2.acc: 99.6094  s2.loss_bbox: 0.0185  s2.loss_mask: 0.0357
# 11/16 00:18:56 - mmengine - INFO - Epoch(train) [22][1900/2510]  lr: 2.5000e-05  eta: 0:02:50  time: 0.2876  data_time: 0.0029  memory: 4238  loss: 0.4576  loss_rpn_cls: 0.0072  loss_rpn_bbox: 0.0048  s0.loss_cls: 0.0579  s0.acc: 97.1680  s0.loss_bbox: 0.0400  s0.loss_mask: 0.1444  s1.loss_cls: 0.0288  s1.acc: 97.6562  s1.loss_bbox: 0.0383  s1.loss_mask: 0.0705  s2.loss_cls: 0.0118  s2.acc: 98.1445  s2.loss_bbox: 0.0178  s2.loss_mask: 0.0360
# 11/16 00:19:10 - mmengine - INFO - Epoch(train) [22][1950/2510]  lr: 2.5000e-05  eta: 0:02:36  time: 0.2864  data_time: 0.0029  memory: 4238  loss: 0.4669  loss_rpn_cls: 0.0094  loss_rpn_bbox: 0.0042  s0.loss_cls: 0.0703  s0.acc: 98.8281  s0.loss_bbox: 0.0466  s0.loss_mask: 0.1322  s1.loss_cls: 0.0327  s1.acc: 99.2188  s1.loss_bbox: 0.0409  s1.loss_mask: 0.0660  s2.loss_cls: 0.0134  s2.acc: 98.5352  s2.loss_bbox: 0.0175  s2.loss_mask: 0.0337
# 11/16 00:19:24 - mmengine - INFO - Epoch(train) [22][2000/2510]  lr: 2.5000e-05  eta: 0:02:22  time: 0.2837  data_time: 0.0030  memory: 3783  loss: 0.4939  loss_rpn_cls: 0.0094  loss_rpn_bbox: 0.0048  s0.loss_cls: 0.0697  s0.acc: 98.4375  s0.loss_bbox: 0.0452  s0.loss_mask: 0.1529  s1.loss_cls: 0.0303  s1.acc: 96.3867  s1.loss_bbox: 0.0402  s1.loss_mask: 0.0753  s2.loss_cls: 0.0121  s2.acc: 98.1445  s2.loss_bbox: 0.0177  s2.loss_mask: 0.0364
# 11/16 00:19:39 - mmengine - INFO - Epoch(train) [22][2050/2510]  lr: 2.5000e-05  eta: 0:02:08  time: 0.2849  data_time: 0.0030  memory: 4238  loss: 0.4722  loss_rpn_cls: 0.0084  loss_rpn_bbox: 0.0046  s0.loss_cls: 0.0559  s0.acc: 98.6328  s0.loss_bbox: 0.0440  s0.loss_mask: 0.1530  s1.loss_cls: 0.0277  s1.acc: 98.5352  s1.loss_bbox: 0.0396  s1.loss_mask: 0.0741  s2.loss_cls: 0.0121  s2.acc: 97.8516  s2.loss_bbox: 0.0175  s2.loss_mask: 0.0352
# 11/16 00:19:53 - mmengine - INFO - Epoch(train) [22][2100/2510]  lr: 2.5000e-05  eta: 0:01:54  time: 0.2908  data_time: 0.0030  memory: 4226  loss: 0.4558  loss_rpn_cls: 0.0087  loss_rpn_bbox: 0.0041  s0.loss_cls: 0.0580  s0.acc: 98.7305  s0.loss_bbox: 0.0402  s0.loss_mask: 0.1379  s1.loss_cls: 0.0281  s1.acc: 98.9258  s1.loss_bbox: 0.0390  s1.loss_mask: 0.0702  s2.loss_cls: 0.0131  s2.acc: 97.6562  s2.loss_bbox: 0.0212  s2.loss_mask: 0.0353
# 11/16 00:20:08 - mmengine - INFO - Epoch(train) [22][2150/2510]  lr: 2.5000e-05  eta: 0:01:40  time: 0.2895  data_time: 0.0032  memory: 4238  loss: 0.4706  loss_rpn_cls: 0.0078  loss_rpn_bbox: 0.0044  s0.loss_cls: 0.0632  s0.acc: 98.4375  s0.loss_bbox: 0.0425  s0.loss_mask: 0.1407  s1.loss_cls: 0.0288  s1.acc: 99.0234  s1.loss_bbox: 0.0411  s1.loss_mask: 0.0710  s2.loss_cls: 0.0134  s2.acc: 99.3164  s2.loss_bbox: 0.0210  s2.loss_mask: 0.0367
# 11/16 00:20:22 - mmengine - INFO - Epoch(train) [22][2200/2510]  lr: 2.5000e-05  eta: 0:01:26  time: 0.2875  data_time: 0.0029  memory: 3868  loss: 0.4448  loss_rpn_cls: 0.0081  loss_rpn_bbox: 0.0049  s0.loss_cls: 0.0641  s0.acc: 97.2656  s0.loss_bbox: 0.0422  s0.loss_mask: 0.1328  s1.loss_cls: 0.0315  s1.acc: 98.0469  s1.loss_bbox: 0.0408  s1.loss_mask: 0.0593  s2.loss_cls: 0.0131  s2.acc: 98.8281  s2.loss_bbox: 0.0189  s2.loss_mask: 0.0291
# 11/16 00:20:37 - mmengine - INFO - Epoch(train) [22][2250/2510]  lr: 2.5000e-05  eta: 0:01:12  time: 0.2900  data_time: 0.0030  memory: 3708  loss: 0.4378  loss_rpn_cls: 0.0082  loss_rpn_bbox: 0.0067  s0.loss_cls: 0.0555  s0.acc: 97.4609  s0.loss_bbox: 0.0383  s0.loss_mask: 0.1345  s1.loss_cls: 0.0274  s1.acc: 97.0703  s1.loss_bbox: 0.0381  s1.loss_mask: 0.0648  s2.loss_cls: 0.0120  s2.acc: 98.0469  s2.loss_bbox: 0.0191  s2.loss_mask: 0.0330
# 11/16 00:20:48 - mmengine - INFO - Exp name: htc-without-semantic_r50_fpn_1x_coco_20231115_182203
# 11/16 00:20:51 - mmengine - INFO - Epoch(train) [22][2300/2510]  lr: 2.5000e-05  eta: 0:00:58  time: 0.2847  data_time: 0.0030  memory: 4238  loss: 0.4589  loss_rpn_cls: 0.0087  loss_rpn_bbox: 0.0053  s0.loss_cls: 0.0590  s0.acc: 97.4609  s0.loss_bbox: 0.0394  s0.loss_mask: 0.1439  s1.loss_cls: 0.0294  s1.acc: 98.3398  s1.loss_bbox: 0.0379  s1.loss_mask: 0.0711  s2.loss_cls: 0.0121  s2.acc: 99.0234  s2.loss_bbox: 0.0162  s2.loss_mask: 0.0357
# 11/16 00:21:05 - mmengine - INFO - Epoch(train) [22][2350/2510]  lr: 2.5000e-05  eta: 0:00:44  time: 0.2900  data_time: 0.0030  memory: 4233  loss: 0.4184  loss_rpn_cls: 0.0074  loss_rpn_bbox: 0.0042  s0.loss_cls: 0.0504  s0.acc: 99.4141  s0.loss_bbox: 0.0383  s0.loss_mask: 0.1294  s1.loss_cls: 0.0249  s1.acc: 99.7070  s1.loss_bbox: 0.0366  s1.loss_mask: 0.0651  s2.loss_cls: 0.0115  s2.acc: 99.6094  s2.loss_bbox: 0.0168  s2.loss_mask: 0.0338
# 11/16 00:21:20 - mmengine - INFO - Epoch(train) [22][2400/2510]  lr: 2.5000e-05  eta: 0:00:30  time: 0.2908  data_time: 0.0031  memory: 4238  loss: 0.4309  loss_rpn_cls: 0.0087  loss_rpn_bbox: 0.0055  s0.loss_cls: 0.0595  s0.acc: 97.8516  s0.loss_bbox: 0.0412  s0.loss_mask: 0.1254  s1.loss_cls: 0.0295  s1.acc: 97.4609  s1.loss_bbox: 0.0402  s1.loss_mask: 0.0604  s2.loss_cls: 0.0120  s2.acc: 98.3398  s2.loss_bbox: 0.0185  s2.loss_mask: 0.0298
# 11/16 00:21:34 - mmengine - INFO - Epoch(train) [22][2450/2510]  lr: 2.5000e-05  eta: 0:00:16  time: 0.2838  data_time: 0.0030  memory: 4238  loss: 0.4396  loss_rpn_cls: 0.0093  loss_rpn_bbox: 0.0046  s0.loss_cls: 0.0670  s0.acc: 98.1445  s0.loss_bbox: 0.0433  s0.loss_mask: 0.1222  s1.loss_cls: 0.0302  s1.acc: 98.3398  s1.loss_bbox: 0.0391  s1.loss_mask: 0.0613  s2.loss_cls: 0.0123  s2.acc: 98.7305  s2.loss_bbox: 0.0186  s2.loss_mask: 0.0316
# 11/16 00:21:48 - mmengine - INFO - Epoch(train) [22][2500/2510]  lr: 2.5000e-05  eta: 0:00:02  time: 0.2901  data_time: 0.0030  memory: 3769  loss: 0.4684  loss_rpn_cls: 0.0085  loss_rpn_bbox: 0.0050  s0.loss_cls: 0.0678  s0.acc: 97.8516  s0.loss_bbox: 0.0481  s0.loss_mask: 0.1337  s1.loss_cls: 0.0323  s1.acc: 97.9492  s1.loss_bbox: 0.0426  s1.loss_mask: 0.0651  s2.loss_cls: 0.0127  s2.acc: 98.3398  s2.loss_bbox: 0.0199  s2.loss_mask: 0.0327
# 11/16 00:21:51 - mmengine - INFO - Exp name: htc-without-semantic_r50_fpn_1x_coco_20231115_182203
# 11/16 00:21:51 - mmengine - INFO - Saving checkpoint at 22 epochs
# 11/16 00:22:06 - mmengine - INFO - Epoch(val) [22][ 50/946]    eta: 0:03:33  time: 0.2384  data_time: 0.0010  memory: 3421
# 11/16 00:22:15 - mmengine - INFO - Epoch(val) [22][100/946]    eta: 0:03:00  time: 0.1883  data_time: 0.0007  memory: 2739
# 11/16 00:22:30 - mmengine - INFO - Epoch(val) [22][150/946]    eta: 0:03:12  time: 0.2975  data_time: 0.0008  memory: 2863
# 11/16 00:22:49 - mmengine - INFO - Epoch(val) [22][200/946]    eta: 0:03:24  time: 0.3727  data_time: 0.0010  memory: 4000
# 11/16 00:23:06 - mmengine - INFO - Epoch(val) [22][250/946]    eta: 0:03:21  time: 0.3504  data_time: 0.0010  memory: 2712
# 11/16 00:23:19 - mmengine - INFO - Epoch(val) [22][300/946]    eta: 0:03:03  time: 0.2532  data_time: 0.0008  memory: 2913
# 11/16 00:23:31 - mmengine - INFO - Epoch(val) [22][350/946]    eta: 0:02:46  time: 0.2530  data_time: 0.0009  memory: 2688
# 11/16 00:23:49 - mmengine - INFO - Epoch(val) [22][400/946]    eta: 0:02:36  time: 0.3417  data_time: 0.0007  memory: 2688
# 11/16 00:24:02 - mmengine - INFO - Epoch(val) [22][450/946]    eta: 0:02:21  time: 0.2755  data_time: 0.0009  memory: 3350
# 11/16 00:24:18 - mmengine - INFO - Epoch(val) [22][500/946]    eta: 0:02:09  time: 0.3223  data_time: 0.0008  memory: 2849
# 11/16 00:24:38 - mmengine - INFO - Epoch(val) [22][550/946]    eta: 0:01:58  time: 0.3932  data_time: 0.0008  memory: 3350
# 11/16 00:24:50 - mmengine - INFO - Epoch(val) [22][600/946]    eta: 0:01:41  time: 0.2302  data_time: 0.0009  memory: 2630
# 11/16 00:25:03 - mmengine - INFO - Epoch(val) [22][650/946]    eta: 0:01:26  time: 0.2667  data_time: 0.0009  memory: 2756
# 11/16 00:25:15 - mmengine - INFO - Epoch(val) [22][700/946]    eta: 0:01:10  time: 0.2458  data_time: 0.0009  memory: 3160
# 11/16 00:25:29 - mmengine - INFO - Epoch(val) [22][750/946]    eta: 0:00:56  time: 0.2697  data_time: 0.0008  memory: 2731
# 11/16 00:25:42 - mmengine - INFO - Epoch(val) [22][800/946]    eta: 0:00:41  time: 0.2631  data_time: 0.0009  memory: 2771
# 11/16 00:26:00 - mmengine - INFO - Epoch(val) [22][850/946]    eta: 0:00:27  time: 0.3547  data_time: 0.0008  memory: 3352
# 11/16 00:26:15 - mmengine - INFO - Epoch(val) [22][900/946]    eta: 0:00:13  time: 0.2985  data_time: 0.0010  memory: 3350
# 11/16 00:26:30 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.18s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.82s).
# Accumulating evaluation results...
# DONE (t=1.00s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.199
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.331
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.237
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.105
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.529
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.529
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.529
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.240
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.553
# 11/16 00:26:32 - mmengine - INFO - bbox_mAP_copypaste: 0.199 0.331 0.237 0.000 0.105 0.210
# 11/16 00:26:32 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.51s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=1.29s).
# Accumulating evaluation results...
# DONE (t=1.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.227
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.341
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.244
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.242
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.073
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.598
# 11/16 00:26:36 - mmengine - INFO - segm_mAP_copypaste: 0.227 0.341 0.244 0.000 0.002 0.242
# 11/16 00:26:36 - mmengine - INFO - Epoch(val) [22][946/946]    coco/bbox_mAP: 0.1990  coco/bbox_mAP_50: 0.3310  coco/bbox_mAP_75: 0.2370  coco/bbox_mAP_s: 0.0000  coco/bbox_mAP_m: 0.1050  coco/bbox_mAP_l: 0.2100  coco/segm_mAP: 0.2270  coco/segm_mAP_50: 0.3410  coco/segm_mAP_75: 0.2440  coco/segm_mAP_s: 0.0000  coco/segm_mAP_m: 0.0020  coco/segm_mAP_l: 0.2420  data_time: 0.0009  time: 0.2890
# c:\Users\asiclab\anaconda3\envs\openmmlab\lib\site-packages\mmdet\models\roi_heads\mask_heads\fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#   mask_preds = bboxes.new_tensor(mask_preds)

# %%
work_dir = "./log_mmdet"
checkpoint_file = os.path.join(work_dir, "epoch_22.pth")
assert os.path.isfile(
    checkpoint_file), '`{}` not exist'.format(checkpoint_file)
checkpoint_file = os.path.abspath(checkpoint_file)
checkpoint_file

config_fname = './log_mmdet/htc-without-semantic_r50_fpn_1x_coco.py'

# %%
#Lets visualize some results
import time
import matplotlib
import matplotlib.pylab as plt
plt.rcParams["axes.grid"] = False

import mmcv
# from mmcv.runner import load_checkpoint
import mmcv.visualization.image as mmcv_image
# fix for colab

def imshow(img, win_name='', wait_time=0): plt.figure(
    figsize=(50, 50)); plt.imshow(img)


mmcv_image.imshow = imshow
# from mmdet.models import build_detector
from mmdet.apis import init_detector, inference_detector
from mmdet.registry import VISUALIZERS
import cv2
import mmcv


# build the model from a config file and a checkpoint file
model = init_detector(config_fname, checkpoint_file, device='cpu')

visualizer = VISUALIZERS.build(model.cfg.visualizer)
visualizer.dataset_meta = model.dataset_meta
# test a single image and show the results
img = './data/train/images/006509.jpg'   #you can change this to any image you want!
img = cv2. imread(img)
result = inference_detector(model, img)

img = mmcv.imconvert(img, 'bgr', 'rgb')
visualizer.add_datasample(
name='result',
image=img,
data_sample=result,
draw_gt=False,
pred_score_thr=0.3,
show=False)

img = visualizer.get_image()
img = mmcv.imconvert(img, 'bgr', 'rgb')
cv2.imshow('result', img)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Loads checkpoint by local backend from path: c:\Users\asiclab\Desktop\실전 딥러닝\project\log_mmdet\epoch_22.pth
